# %% [markdown]
# # Using MongoDB in Jupyter with WE1S Data
#
# This notebook documents metods of using MongoDB in Jupyter.
# It reviews some basics, then focuses on working with WE1S data -- for example:
#
# 1. notebook import of articles based on a database search
# 2. database import of zip collections
# 3. updating articles in the database
# 4. ...
#
# ### GENERAL REFERENCE
#
# -  https://api.mongodb.com/python/3.0.3/tutorial.html
# -  https://realpython.com/introduction-to-mongodb-and-python/
# -  https://www.mongodb.com/blog/post/getting-started-with-python-and-mongodb
# -  https://docs.mongodb.com/manual/core/databases-and-collections/
# -  https://docs.mongodb.com/manual/tutorial/project-fields-from-query-results/
# -  https://docs.mongodb.com/manual/reference/program/mongoimport/
#
# For performance checks, add `%%time` to the first line of any cell.

# %% [markdown]
# ## Connecting, Databases and Collections

# %%
import json
import os
import pprint
pp = pprint.PrettyPrinter(indent=2, compact=False)

# %%
# import mongodb package

from pymongo import MongoClient 
from pymongo.errors import DuplicateKeyError, InvalidDocument

# %%
import sys
sys.path.insert(0, '/home/jovyan/utils/preprocessing/')

from libs.fuzzyhasher.fuzzyhasher import FuzzyHasher
from libs.zipeditor.zipeditor import ZipEditor, zip_scanner, zip_scanner_excludedirs, ZipProcessor
from we1s_utils.ziputils import BatchJSONUploader

# %% [markdown]
# ## Setup connection

# %%
# connect with MongoDB URI:

client = MongoClient('mongodb://mongo/')
db = client['we1s']
corpus = db['Corpus'] ## REVISE AND IN BELOW CODE
coll = db['humanities_keywords']

# %%
print('Passing and info: db and client are recoverable from collection object.\n')
print(coll)
print(coll.name)
print(coll.database)
print(coll.database.name)
print(coll.database.client)
print(db.name)
print(db.client)
# Out:
# Passing and info: db and client are recoverable from collection object.
#
# Collection(Database(MongoClient(host=['mongo:27017'], document_class=dict, tz_aware=False, connect=True), 'we1s'), 'humanities_keywords')
# humanities_keywords
# Database(MongoClient(host=['mongo:27017'], document_class=dict, tz_aware=False, connect=True), 'we1s')
# we1s
# MongoClient(host=['mongo:27017'], document_class=dict, tz_aware=False, connect=True)
# we1s
# MongoClient(host=['mongo:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
def search_articles_source(collection, source):
    hits = 0
    query = { 'sources': { '$regex' : source } }
    client = MongoClient('mongodb://mongo/')
    result = client['we1s'][collection].find_one(query)
    pp.pprint(result)
    print('count:', hits)

# %%
search_articles_source('humanities_keywords', 'bangor')
# Out:
# { '_id': ObjectId('5d3a9ee9f123b8357f3e0c7e'),
#   'attachment_id': '',
#   'author': '',
#   'content': 'COLLEGE NAC Championships UM-Farmington women 41, Castleton '
#              'State 45, Mount Ida 67, Johnson State 69, Elms, Bay Path, Lasell '
#              'no team scores 1. Andrew Spearrin (UMF) 22:00. 4, 2. Katie '
#              'Sprowl (Castleton) 22:39. 7, 3. Stacey Sarber (MI) 23:07. 8, 4. '
#              'Jen Dickie (Johnson) 23:24. 8, 5. Michelle Bird (Castleton) '
#              '23:41. 1, 6. Kathryn Dickinson (UMF) 24:51. 5, 7. Paque Render '
#              "(Johnson) 24:26. 9, 8. Misty O'Brien (UMF) 24:29. 6, 9. Erika "
#              'Hoddinott (UMF) 24:30. 4, 10. Yvonne Olney (Castleton) 24:41. 5, '
#              '11. Danielle Ring (MI) 25:22. 3, 12. Liliana German (Johnson) '
#              '25:41. 9, 13. Beth Pantzer (Castleton) 25:49. 7, 14. Christine '
#              'Palleschi (MI) 25:53. 1, 15. Ariel Delany (Castleton) 26:54. 1 '
#              'UM-Farmington men 17, Johnson State 53, Castleton State 75, '
#              'Maine Maritime Academy 102, Elms, Lasell no team scores 1. Ben '
#              'Fletcher (UMF) 28:02. 3, 2. Joseph Fitzsimmons (UMF) 28:09. 9, '
#              '3. Nick Scott (UMF) 28:34. 4, 4. Drew Croteau (UMF) 28:45. 9, 5. '
#              'Marc Newcomb (Castleton) 29:14. 1, 6. Gabriel McConkey (Johnson) '
#              '29:24. 4, 7. Andrew Sweeney (UMF) 29:40. 4, 8. Mati Zoffoll '
#              '(Johnson) 30:04. 6, 9. Keenan White (Castleton) 30:06. 7, 10. '
#              'Tharjaith Rout (UMF) 30:29. 0, 11. Philip Jackson (UMF) 30:34. '
#              '0, 12. Jonathan Chin (UMF) 31:09. 9, 13. Adam Reynolds (Johnson) '
#              '31:21. 6, 14. Andrew Gunlach (Lasell) 31:27. 1, 15. Chris Biron '
#              '(Elms) 32:05. 4 At Waterville NESCAC Championships Men, 8K Tufts '
#              '43, Williams 62, Bates 115, Connecticut College 128, Wesleyan '
#              '131, Amherst 137, Middlebury 157, Bowdoin 171, Trinity 203, '
#              'Colby 258, Hamilton 352 1. Neal Holtschulte (Williams) 25:20. '
#              '97, 2. Weston Fuhrman (Wesleyan), 3. Stephen Wills (Williams) '
#              '25:39. 20, 4. Matthew Lacey (Tufts) 25:40. 11, 5. Owen Kiely '
#              '(Wesleyan) 25:43. 68, 6. Sam Van Volkenburgh (Williams) 25:43. '
#              '68, 7. Joshua Kennedy (Tufts) 25:45. 52, 8. Biran McNamara '
#              '(Tufts) 25:46. 97, 9. Nathan Brigham (Tufts) 25:48. 45, 10. Dan '
#              'Johnson (Bates) 25:50. 27 Women, 5K Williams 59, Middlebury 59, '
#              'Amherst 95, Colby 127, Wesleyan 130, Tufts 141, Trinity 169, 8. '
#              'Bowdoin 204, Bates 220, Connecticut College 267, Hamilton 319 1. '
#              'Caroline Cretti (Williams) 17:48. 15, 2. Jessica Manzer '
#              '(Middlebury) 17:57. 16, 3. Carter Hamill (Amherst) 17:58. 66, 4. '
#              'Jenn Campbell (Williams) 18:10. 65, 5. Shauneen Garrahan '
#              '(Amherst) 18:19. 36, 6. Courtney Quirin (Wesleyan) 18:22. 28, 7. '
#              'Marlsa Cawley (Middlebury) 18:30. 41, 8. Margaret Davis '
#              '(Wesleyan) 18:39. 33, 9. Ellen Beth (Bowdoin) 18:49. 70, 10. '
#              'Andrea Giddings (Middlebury) 18:50. 38 America East '
#              'Championships Men, 8K Maine 28, New Hampshire 58, Stony Brook '
#              '71, Albany 76, Maryland Baltimore County 118, Boston University '
#              '165, Binghamton 194, Vermont 201, Northeastern 280, Hartford 300 '
#              'Top 5: 1. Anthony Truax (NH) 24:27. 00, 2. Michael Lansing '
#              '(Maine) 24:31. 40, 3. Dale Summerville (Stony Brook) 24:32. 20, '
#              '4. Jeff Caron (Maine) 24:32. 80, 5. Edward Caron (Maine) 24:38. '
#              '60 UMaine finishers: 2. Michael Lansing 24:31. 40, 4. Jeff Caron '
#              '24:32. 80, 5. Edward Caron 24:38. 60, 8. Kirby Davis 24:44. 40, '
#              '9. Donald Drake 24:46. 50, 38. Joshua Trevino 26:25. 40, 40. '
#              'Paul Rupprecht 26:31. 70, 44. Jon McGonagle 26:44. 80, 45. '
#              'Charles Therriault 26:44. 90 Women, 5K Boston University 27, New '
#              'Hampshire 85, Stony Brook 93, Binghamton 117, Vermont 139, '
#              'Albany 160, UMBC 164, Northeastern 173, Maine 188, Hartford 330 '
#              'Top 5: 1. Victoria Botticelli (Boston) 17:22. 50, 2. Leonora Joy '
#              '(Stony Brook) 17:31. 80, 3. Abbey Sadowski (Boston) 17:35. 10, '
#              '4. Caitlin Hayes (New Hampshire) 17:35. 20, 5. Marissa Ryan '
#              '17:38. 80 UMaine finishers: 9. Hana Pelletier 18:01. 80, 41. '
#              'Tieg Choroszy 19:12. 50, 42. Shelby Howe 19:13. 30, 49. Brie '
#              'Jellison 19:26. 70, 57. Charlotte Howley 19:44. 90, 58. Miranda '
#              'Szwec 19:48. 40, 59. Kristen Vidlak 19:49. 10, 71. Erin Lawler '
#              '20:29. 00, 74. Jessica Hudec 20:48. 80 New England Alliance '
#              'Championship Men, 8K Keene State 23, Southern Maine 78, '
#              'Westfield State 112, Rhode Island 129, Massachusetts Maritime '
#              '136, UMass Dartmouth 168, Bridgewater State 172, Fitchburg State '
#              '175, Eastern Connecticut 236, Salem State 249, Worcester State '
#              '283, Mass. College of Liberal Arts 360 Top 5: 1. Dave '
#              'Bridgewater (Keene State) 24:41, 2. Michael Bunker (USM) 25:17, '
#              '3. Ryan Gough (Keene State) 25:21, 4. Joseph Hegerty (Keene '
#              'State) 25:30, 5. Fabian Mejia (Salem State) 25:33 Southern Maine '
#              'finishers: 2. Michael Bunker 25:17, 11. Curtis Wheeler 26:13, '
#              '19. Emery Bickford 27:03, 20. Forrest Robie 27:03, 37. Kyle '
#              'Smith 28:07, 61. Joe Lizotte 29:51 Women, 5K Keene State 24, '
#              'Southern Maine 73, Westfield Sate 79, UMass Dartmouth 136, UMass '
#              'Boston 144, Bridgewater State 170, Eastern Connecticut 173, '
#              'Worcester State 189, Fitchburg State 222, Mass. Maritime 277 Top '
#              '5: 1. Erin Landon (Keene State) 18:33, 2. Heather Wenninger '
#              '(Westfield) 18:41, 3. Stephanie Gibson (Keene State) 18:43, 4. '
#              'Sarah Shapiro (UMass Boston) 18:44, 5. Laurie Yorgensen (Keene '
#              'State) 18:52 Southern Maine finishers: 6. Sara Marzouk 19:08, '
#              '14. Alora Johnson 20:09, 19. Lindsay Davis 20:36, 21. Colleen '
#              'Dolbec 20:41, 26. Kate Richardson 20:54, 37. Melissa Patten '
#              '21:39, 40. Elizabeth Trask 21:49, 47. Sara Benedetto 22:14, 57. '
#              'Jill Fernandes 23:29, 64. Jessie Hobgood 24:05, 67. Jennifer '
#              'Oliver 24:32, 74. Lindsay Kuhn 25:28, 76. Hattie Landry 25:36',
#   'content-hash-ssdeep': '96:P99990WiwAAdMOsQinVtzmAM6EHRKvLyqtB+ogNDhKQkaZ0MKYBQ/C9tx:P99990WvGiK1mAM69vOqtjgRhKgZJKqr',
#   'content-unscrubbed': 'COLLEGE NAC Championships UM-Farmington women 41, '
#                         'Castleton State 45, Mount Ida 67, Johnson State 69, '
#                         'Elms, Bay Path, Lasell no team scores 1. Andrew '
#                         'Spearrin (UMF) 22:00.4, 2. Katie Sprowl (Castleton) '
#                         '22:39.7, 3. Stacey Sarber (MI) 23:07.8, 4. Jen Dickie '
#                         '(Johnson) 23:24.8, 5. Michelle Bird (Castleton) '
#                         '23:41.1, 6. Kathryn Dickinson (UMF) 24:51.5, 7. Paque '
#                         "Render (Johnson) 24:26.9, 8. Misty O'Brien (UMF) "
#                         '24:29.6, 9. Erika Hoddinott (UMF) 24:30.4, 10. Yvonne '
#                         'Olney (Castleton) 24:41.5, 11. Danielle Ring (MI) '
#                         '25:22.3, 12. Liliana German (Johnson) 25:41.9, 13. '
#                         'Beth Pantzer (Castleton) 25:49.7, 14. Christine '
#                         'Palleschi (MI) 25:53.1, 15. Ariel Delany (Castleton) '
#                         '26:54.1 UM-Farmington men 17, Johnson State 53, '
#                         'Castleton State 75, Maine Maritime Academy 102, Elms, '
#                         'Lasell no team scores 1. Ben Fletcher (UMF) 28:02.3, '
#                         '2. Joseph Fitzsimmons (UMF) 28:09.9, 3. Nick Scott '
#                         '(UMF) 28:34.4, 4. Drew Croteau (UMF) 28:45.9, 5. Marc '
#                         'Newcomb (Castleton) 29:14.1, 6. Gabriel McConkey '
#                         '(Johnson) 29:24.4, 7. Andrew Sweeney (UMF) 29:40.4, '
#                         '8. Mati Zoffoll (Johnson) 30:04.6, 9. Keenan White '
#                         '(Castleton) 30:06.7, 10. Tharjaith Rout (UMF) '
#                         '30:29.0, 11. Philip Jackson (UMF) 30:34.0, 12. '
#                         'Jonathan Chin (UMF) 31:09.9, 13. Adam Reynolds '
#                         '(Johnson) 31:21.6, 14. Andrew Gunlach (Lasell) '
#                         '31:27.1, 15. Chris Biron (Elms) 32:05.4 At Waterville '
#                         'NESCAC Championships Men, 8K Tufts 43, Williams 62, '
#                         'Bates 115, Connecticut College 128, Wesleyan 131, '
#                         'Amherst 137, Middlebury 157, Bowdoin 171, Trinity '
#                         '203, Colby 258, Hamilton 352 1. Neal Holtschulte '
#                         '(Williams) 25:20.97, 2. Weston Fuhrman (Wesleyan), 3. '
#                         'Stephen Wills (Williams) 25:39.20, 4. Matthew Lacey '
#                         '(Tufts) 25:40.11, 5. Owen Kiely (Wesleyan) 25:43.68, '
#                         '6. Sam Van Volkenburgh (Williams) 25:43.68, 7. Joshua '
#                         'Kennedy (Tufts) 25:45.52, 8. Biran McNamara (Tufts) '
#                         '25:46.97, 9. Nathan Brigham (Tufts) 25:48.45, 10. Dan '
#                         'Johnson (Bates) 25:50.27 Women, 5K Williams 59, '
#                         'Middlebury 59, Amherst 95, Colby 127, Wesleyan 130, '
#                         'Tufts 141, Trinity 169, 8. Bowdoin 204, Bates 220, '
#                         'Connecticut College 267, Hamilton 319 1. Caroline '
#                         'Cretti (Williams) 17:48.15, 2. Jessica Manzer '
#                         '(Middlebury) 17:57.16, 3. Carter Hamill (Amherst) '
#                         '17:58.66, 4. Jenn Campbell (Williams) 18:10.65, 5. '
#                         'Shauneen Garrahan (Amherst) 18:19.36, 6. Courtney '
#                         'Quirin (Wesleyan) 18:22.28, 7. Marlsa Cawley '
#                         '(Middlebury) 18:30.41, 8. Margaret Davis (Wesleyan) '
#                         '18:39.33, 9. Ellen Beth (Bowdoin) 18:49.70, 10. '
#                         'Andrea Giddings (Middlebury) 18:50.38 America East '
#                         'Championships Men, 8K Maine 28, New Hampshire 58, '
#                         'Stony Brook 71, Albany 76, Maryland Baltimore County '
#                         '118, Boston University 165, Binghamton 194, Vermont '
#                         '201, Northeastern 280, Hartford 300 Top 5: 1. Anthony '
#                         'Truax (NH) 24:27.00, 2. Michael Lansing (Maine) '
#                         '24:31.40, 3. Dale Summerville (Stony Brook) 24:32.20, '
#                         '4. Jeff Caron (Maine) 24:32.80, 5. Edward Caron '
#                         '(Maine) 24:38.60 UMaine finishers: 2. Michael Lansing '
#                         '24:31.40, 4. Jeff Caron 24:32.80, 5. Edward Caron '
#                         '24:38.60, 8. Kirby Davis 24:44.40, 9. Donald Drake '
#                         '24:46.50, 38. Joshua Trevino 26:25.40, 40. Paul '
#                         'Rupprecht 26:31.70, 44. Jon McGonagle 26:44.80, 45. '
#                         'Charles Therriault 26:44.90 Women, 5K Boston '
#                         'University 27, New Hampshire 85, Stony Brook 93, '
#                         'Binghamton 117, Vermont 139, Albany 160, UMBC 164, '
#                         'Northeastern 173, Maine 188, Hartford 330 Top 5: 1. '
#                         'Victoria Botticelli (Boston) 17:22.50, 2. Leonora Joy '
#                         '(Stony Brook) 17:31.80, 3. Abbey Sadowski (Boston) '
#                         '17:35.10, 4. Caitlin Hayes (New Hampshire) 17:35.20, '
#                         '5. Marissa Ryan 17:38.80 UMaine finishers: 9. Hana '
#                         'Pelletier 18:01.80, 41. Tieg Choroszy 19:12.50, 42. '
#                         'Shelby Howe 19:13.30, 49. Brie Jellison 19:26.70, 57. '
#                         'Charlotte Howley 19:44.90, 58. Miranda Szwec '
#                         '19:48.40, 59. Kristen Vidlak 19:49.10, 71. Erin '
#                         'Lawler 20:29.00, 74. Jessica Hudec 20:48.80 New '
#                         'England Alliance Championship Men, 8K Keene State 23, '
#                         'Southern Maine 78, Westfield State 112, Rhode Island '
#                         '129, Massachusetts Maritime 136, UMass Dartmouth 168, '
#                         'Bridgewater State 172, Fitchburg State 175, Eastern '
#                         'Connecticut 236, Salem State 249, Worcester State '
#                         '283, Mass. College of Liberal Arts 360 Top 5: 1. Dave '
#                         'Bridgewater (Keene State) 24:41, 2. Michael Bunker '
#                         '(USM) 25:17, 3. Ryan Gough (Keene State) 25:21, 4. '
#                         'Joseph Hegerty (Keene State) 25:30, 5. Fabian Mejia '
#                         '(Salem State) 25:33 Southern Maine finishers: 2. '
#                         'Michael Bunker 25:17, 11. Curtis Wheeler 26:13, 19. '
#                         'Emery Bickford 27:03, 20. Forrest Robie 27:03, 37. '
#                         'Kyle Smith 28:07, 61. Joe Lizotte 29:51 Women, 5K '
#                         'Keene State 24, Southern Maine 73, Westfield Sate 79, '
#                         'UMass Dartmouth 136, UMass Boston 144, Bridgewater '
#                         'State 170, Eastern Connecticut 173, Worcester State '
#                         '189, Fitchburg State 222, Mass. Maritime 277 Top 5: '
#                         '1. Erin Landon (Keene State) 18:33, 2. Heather '
#                         'Wenninger (Westfield) 18:41, 3. Stephanie Gibson '
#                         '(Keene State) 18:43, 4. Sarah Shapiro (UMass Boston) '
#                         '18:44, 5. Laurie Yorgensen (Keene State) 18:52 '
#                         'Southern Maine finishers: 6. Sara Marzouk 19:08, 14. '
#                         'Alora Johnson 20:09, 19. Lindsay Davis 20:36, 21. '
#                         'Colleen Dolbec 20:41, 26. Kate Richardson 20:54, 37. '
#                         'Melissa Patten 21:39, 40. Elizabeth Trask 21:49, 47. '
#                         'Sara Benedetto 22:14, 57. Jill Fernandes 23:29, 64. '
#                         'Jessie Hobgood 24:05, 67. Jennifer Oliver 24:32, 74. '
#                         'Lindsay Kuhn 25:28, 76. Hattie Landry 25:36',
#   'copyright': 'Bangor Daily News',
#   'database': 'LexisNexis',
#   'doc_id': '02A6A252C52394AB97B14672E56C2F2F4F90A529D0561AD44F162A5FD25DD2D42EB990EF4D1F01F31872495CF324DE70287550868B34234117E283A6D0D6127BC81C7B134EA715F54976F2DD7DE19E7D1FCA0E2755DF88D520C4470AA8E70F4FDC000126B34741EAAE17C4010FE16A75',
#   'features': [ [ 'TOKEN',
#                   'NORM',
#                   'LEMMA',
#                   'POS',
#                   'TAG',
#                   'STOPWORD',
#                   'ENTITIES'],
#                 [ 'COLLEGE',
#                   'college',
#                   'COLLEGE',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['O', '']],
#                 ['NAC', 'nac', 'NAC', 'PROPN', 'NNP', 'False', ['O', '']],
#                 [ 'Championships',
#                   'championships',
#                   'Championships',
#                   'PROPN',
#                   'NNPS',
#                   'False',
#                   ['O', '']],
#                 ['UM', 'um', 'UM', 'PROPN', 'NNP', 'False', ['O', '']],
#                 ['-', '-', '-', 'PUNCT', 'HYPH', 'False', ['O', '']],
#                 [ 'Farmington',
#                   'farmington',
#                   'Farmington',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['O', '']],
#                 ['women', 'women', 'woman', 'NOUN', 'NNS', 'False', ['O', '']],
#                 ['41', '41', '41', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 [ 'Castleton State 45',
#                   'castleton state 45',
#                   'Castleton',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'FAC']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 [ 'Mount Ida',
#                   'mount ida',
#                   'Mount',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'LOC']],
#                 ['67', '67', '67', 'NUM', 'CD', 'False', ['O', '']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 [ 'Johnson State 69',
#                   'johnson state 69',
#                   'Johnson',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 [ 'Elms',
#                   'elms',
#                   'Elms',
#                   'PROPN',
#                   'NNPS',
#                   'False',
#                   ['B', 'ORG']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 [ 'Bay Path',
#                   'bay path',
#                   'Bay',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'LOC']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 [ 'Lasell',
#                   'lasell',
#                   'Lasell',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['no', 'no', 'no', 'DET', 'DT', 'True', ['O', '']],
#                 ['team', 'team', 'team', 'NOUN', 'NN', 'False', ['O', '']],
#                 [ 'scores',
#                   'scores',
#                   'score',
#                   'VERB',
#                   'VBZ',
#                   'False',
#                   ['O', '']],
#                 ['1', '1', '1', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Andrew Spearrin',
#                   'andrew spearrin',
#                   'Andrew',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['UMF', 'umf', 'UMF', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '22:00',
#                   '22:00',
#                   '22:00',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['4', '4', '4', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['2', '2', '2', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Katie Sprowl',
#                   'katie sprowl',
#                   'Katie',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Castleton',
#                   'castleton',
#                   'Castleton',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '22:39',
#                   '22:39',
#                   '22:39',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['7', '7', '7', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['3', '3', '3', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Stacey Sarber',
#                   'stacey sarber',
#                   'Stacey',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['MI', 'mi', 'MI', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '23:07',
#                   '23:07',
#                   '23:07',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['8', '8', '8', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['4', '4', '4', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Jen Dickie',
#                   'jen dickie',
#                   'Jen',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Johnson',
#                   'johnson',
#                   'Johnson',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '23:24',
#                   '23:24',
#                   '23:24',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'TIME']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['8', '8', '8', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['5', '5', '5', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Michelle Bird',
#                   'michelle bird',
#                   'Michelle',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Castleton',
#                   'castleton',
#                   'Castleton',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '23:41',
#                   '23:41',
#                   '23:41',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['1', '1', '1', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['6', '6', '6', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Kathryn Dickinson',
#                   'kathryn dickinson',
#                   'Kathryn',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['UMF', 'umf', 'UMF', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '24:51',
#                   '24:51',
#                   '24:51',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['5', '5', '5', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['7', '7', '7', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Paque Render',
#                   'paque render',
#                   'Paque',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Johnson',
#                   'johnson',
#                   'Johnson',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['O', '']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '24:26',
#                   '24:26',
#                   '24:26',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['9', '9', '9', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['8', '8', '8', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ "Misty O'Brien",
#                   "misty o'brien",
#                   'Misty',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['UMF', 'umf', 'UMF', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '24:29',
#                   '24:29',
#                   '24:29',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['6', '6', '6', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['9', '9', '9', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['Erika', 'erika', 'Erika', 'PROPN', 'NNP', 'False', ['O', '']],
#                 [ 'Hoddinott',
#                   'hoddinott',
#                   'Hoddinott',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['O', '']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['UMF', 'umf', 'UMF', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '24:30',
#                   '24:30',
#                   '24:30',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['4', '4', '4', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['10', '10', '10', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Yvonne Olney',
#                   'yvonne olney',
#                   'Yvonne',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Castleton',
#                   'castleton',
#                   'Castleton',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'GPE']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '24:41',
#                   '24:41',
#                   '24:41',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['5', '5', '5', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['11', '11', '11', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Danielle Ring',
#                   'danielle ring',
#                   'Danielle',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['MI', 'mi', 'MI', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '25:22',
#                   '25:22',
#                   '25:22',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['3', '3', '3', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['12', '12', '12', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Liliana German',
#                   'liliana german',
#                   'liliana',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Johnson',
#                   'johnson',
#                   'Johnson',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '25:41',
#                   '25:41',
#                   '25:41',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['9', '9', '9', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['13', '13', '13', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Beth Pantzer',
#                   'beth pantzer',
#                   'Beth',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Castleton',
#                   'castleton',
#                   'Castleton',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '25:49',
#                   '25:49',
#                   '25:49',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['7', '7', '7', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['14', '14', '14', 'NUM', 'CD', 'False', ['B', 'DATE']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Christine Palleschi',
#                   'christine palleschi',
#                   'Christine',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['MI', 'mi', 'MI', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '25:53',
#                   '25:53',
#                   '25:53',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['1', '1', '1', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['15', '15', '15', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Ariel Delany',
#                   'ariel delany',
#                   'Ariel',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Castleton',
#                   'castleton',
#                   'Castleton',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '26:54',
#                   '26:54',
#                   '26:54',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['1', '1', '1', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [ 'UM-Farmington',
#                   'um-farmington',
#                   'UM',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 ['men', 'men', 'man', 'NOUN', 'NNS', 'False', ['O', '']],
#                 ['17', '17', '17', 'NUM', 'CD', 'False', ['B', 'DATE']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 [ 'Johnson State 53',
#                   'johnson state 53',
#                   'Johnson',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 [ 'Castleton State 75,',
#                   'castleton state 75,',
#                   'Castleton',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 [ 'Maine Maritime Academy',
#                   'maine maritime academy',
#                   'Maine',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 ['102', '102', '102', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 [ 'Elms',
#                   'elms',
#                   'Elms',
#                   'PROPN',
#                   'NNPS',
#                   'False',
#                   ['B', 'ORG']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 [ 'Lasell',
#                   'lasell',
#                   'lasell',
#                   'VERB',
#                   'VB',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['no', 'no', 'no', 'DET', 'DT', 'True', ['O', '']],
#                 ['team', 'team', 'team', 'NOUN', 'NN', 'False', ['O', '']],
#                 [ 'scores',
#                   'scores',
#                   'score',
#                   'VERB',
#                   'VBZ',
#                   'False',
#                   ['O', '']],
#                 ['1', '1', '1', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Ben Fletcher',
#                   'ben fletcher',
#                   'Ben',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['UMF', 'umf', 'UMF', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '28:02',
#                   '28:02',
#                   '28:02',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['3', '3', '3', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['2', '2', '2', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Joseph Fitzsimmons',
#                   'joseph fitzsimmons',
#                   'Joseph',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['UMF', 'umf', 'UMF', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '28:09',
#                   '28:09',
#                   '28:09',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['9', '9', '9', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['3', '3', '3', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Nick Scott',
#                   'nick scott',
#                   'Nick',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['UMF', 'umf', 'UMF', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '28:34',
#                   '28:34',
#                   '28:34',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['4', '4', '4', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['4', '4', '4', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Drew Croteau',
#                   'drew croteau',
#                   'Drew',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['UMF', 'umf', 'UMF', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '28:45',
#                   '28:45',
#                   '28:45',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['9', '9', '9', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['5', '5', '5', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Marc Newcomb',
#                   'marc newcomb',
#                   'Marc',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Castleton',
#                   'castleton',
#                   'Castleton',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '29:14',
#                   '29:14',
#                   '29:14',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['1', '1', '1', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['6', '6', '6', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Gabriel McConkey',
#                   'gabriel mcconkey',
#                   'Gabriel',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Johnson',
#                   'johnson',
#                   'Johnson',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '29:24',
#                   '29:24',
#                   '29:24',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'TIME']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['4', '4', '4', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['7', '7', '7', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Andrew Sweeney',
#                   'andrew sweeney',
#                   'Andrew',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['UMF', 'umf', 'UMF', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '29:40',
#                   '29:40',
#                   '29:40',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['4', '4', '4', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['8', '8', '8', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Mati Zoffoll',
#                   'mati zoffoll',
#                   'Mati',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Johnson',
#                   'johnson',
#                   'Johnson',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '30:04',
#                   '30:04',
#                   '30:04',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['6', '6', '6', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['9', '9', '9', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Keenan White (',
#                   'keenan white (',
#                   'Keenan',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 [ 'Castleton',
#                   'castleton',
#                   'Castleton',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'GPE']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '30:06',
#                   '30:06',
#                   '30:06',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['7', '7', '7', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['10', '10', '10', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Tharjaith Rout',
#                   'tharjaith rout',
#                   'tharjaith',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['UMF', 'umf', 'UMF', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '30:29',
#                   '30:29',
#                   '30:29',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 ['0', '0', '0', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['11', '11', '11', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Philip Jackson',
#                   'philip jackson',
#                   'Philip',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['UMF', 'umf', 'UMF', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '30:34',
#                   '30:34',
#                   '30:34',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['0', '0', '0', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['12', '12', '12', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Jonathan Chin',
#                   'jonathan chin',
#                   'Jonathan',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 ['UMF', 'umf', 'UMF', 'PROPN', 'NNP', 'False', ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '31:09',
#                   '31:09',
#                   '31:09',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 ['.', '.', '.', 'NOUN', 'NN', 'False', ['O', '']],
#                 ['9', '9', '9', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
# ...
#                 ['Top', 'top', 'Top', 'PROPN', 'NNP', 'True', ['O', '']],
#                 ['5', '5', '5', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 [':', ':', ':', 'SYM', 'SYM', 'False', ['O', '']],
#                 ['1', '1', '1', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Erin Landon',
#                   'erin landon',
#                   'Erin',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Keene State',
#                   'keene state',
#                   'Keene',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '18:33',
#                   '18:33',
#                   '18:33',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['2', '2', '2', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Heather Wenninger',
#                   'heather wenninger',
#                   'Heather',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Westfield',
#                   'westfield',
#                   'Westfield',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['O', '']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 ['18:41', '18:41', '18:41', 'NUM', 'CD', 'False', ['O', '']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['3', '3', '3', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Stephanie Gibson',
#                   'stephanie gibson',
#                   'Stephanie',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Keene State',
#                   'keene state',
#                   'Keene',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '18:43',
#                   '18:43',
#                   '18:43',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'TIME']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['4', '4', '4', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Sarah Shapiro',
#                   'sarah shapiro',
#                   'Sarah',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'UMass Boston',
#                   'umass boston',
#                   'UMass',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '18:44',
#                   '18:44',
#                   '18:44',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['5', '5', '5', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Laurie Yorgensen',
#                   'laurie yorgensen',
#                   'Laurie',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['(', '(', '(', 'PUNCT', '-LRB-', 'False', ['O', '']],
#                 [ 'Keene State',
#                   'keene state',
#                   'Keene',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 [')', ')', ')', 'PUNCT', '-RRB-', 'False', ['O', '']],
#                 [ '18:52',
#                   '18:52',
#                   '18:52',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 [ 'Southern Maine',
#                   'southern maine',
#                   'Southern',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'ORG']],
#                 [ 'finishers',
#                   'finishers',
#                   'finisher',
#                   'NOUN',
#                   'NNS',
#                   'False',
#                   ['O', '']],
#                 [':', ':', ':', 'PUNCT', ':', 'False', ['O', '']],
#                 ['6', '6', '6', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Sara Marzouk',
#                   'sara marzouk',
#                   'Sara',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['19:08', '19:08', '19:08', 'NUM', 'CD', 'False', ['O', '']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['14', '14', '14', 'NUM', 'CD', 'False', ['B', 'DATE']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Alora Johnson 20:09',
#                   'alora johnson 20:09',
#                   'Alora',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['19', '19', '19', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Lindsay Davis',
#                   'lindsay davis',
#                   'Lindsay',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 [ '20:36',
#                   '20:36',
#                   '20:36',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['21', '21', '21', 'NUM', 'CD', 'False', ['B', 'DATE']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Colleen Dolbec',
#                   'colleen dolbec',
#                   'Colleen',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 [ '20:41',
#                   '20:41',
#                   '20:41',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['26', '26', '26', 'NUM', 'CD', 'False', ['B', 'CARDINAL']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Kate Richardson',
#                   'kate richardson',
#                   'Kate',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 [ '20:54',
#                   '20:54',
#                   '20:54',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['I', 'DATE']],
#                 ['37', '37', '37', 'NUM', 'CD', 'False', ['I', 'DATE']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Melissa Patten',
#                   'melissa patten',
#                   'Melissa',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['21:39', '21:39', '21:39', 'NUM', 'CD', 'False', ['O', '']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['40', '40', '40', 'NUM', 'CD', 'False', ['B', 'DATE']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Elizabeth Trask',
#                   'elizabeth trask',
#                   'Elizabeth',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 [ '21:49',
#                   '21:49',
#                   '21:49',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['I', 'DATE']],
#                 ['47', '47', '47', 'NUM', 'CD', 'False', ['I', 'DATE']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Sara Benedetto 22:14,',
#                   'sara benedetto 22:14,',
#                   'Sara',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['57', '57', '57', 'NUM', 'CD', 'False', ['O', '']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Jill Fernandes',
#                   'jill fernandes',
#                   'Jill',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 [ '23:29',
#                   '23:29',
#                   '23:29',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'CARDINAL']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['64', '64', '64', 'NUM', 'CD', 'False', ['B', 'DATE']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Jessie Hobgood',
#                   'jessie hobgood',
#                   'Jessie',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 [ '24:05',
#                   '24:05',
#                   '24:05',
#                   'NUM',
#                   'CD',
#                   'False',
#                   ['B', 'DATE']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['I', 'DATE']],
#                 ['67', '67', '67', 'NUM', 'CD', 'False', ['I', 'DATE']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Jennifer Oliver 24:32',
#                   'jennifer oliver 24:32',
#                   'Jennifer',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['74', '74', '74', 'NUM', 'CD', 'False', ['B', 'DATE']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Lindsay Kuhn',
#                   'lindsay kuhn',
#                   'Lindsay',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['25:28', '25:28', '25:28', 'NUM', 'CD', 'False', ['O', '']],
#                 [',', ',', ',', 'PUNCT', ',', 'False', ['O', '']],
#                 ['76', '76', '76', 'NUM', 'CD', 'False', ['B', 'DATE']],
#                 ['.', '.', '.', 'PUNCT', '.', 'False', ['O', '']],
#                 [ 'Hattie Landry',
#                   'hattie landry',
#                   'Hattie',
#                   'PROPN',
#                   'NNP',
#                   'False',
#                   ['B', 'PERSON']],
#                 ['25:36', '25:36', '25:36', 'NUM', 'CD', 'False', ['O', '']]],
#   'language_model': { 'accuracy': { 'ents_f': 85.8587845242,
#                                     'ents_p': 86.3317889027,
#                                     'ents_r': 85.3909350025,
#                                     'las': 89.6616629074,
#                                     'tags_acc': 96.7783856079,
#                                     'token_acc': 99.0697323163,
#                                     'uas': 91.5287392082},
#                       'author': 'Explosion AI',
#                       'custom': { 'add_stopwords': [],
#                                   'infix_re': "re.compile('[-~]')",
#                                   'lemmatization_cases': { 'humanities': [ { '65': 'humanities',
#                                                                              '73': 'humanities',
#                                                                              '74': 'NOUN',
#                                                                              '75': 'NNS'}]},
#                                   'linebreak_regex': "re.compile('((\\\\r\\\\n)|[\\\\n\\\\v])+')",
#                                   'nonbreak_regex': "re.compile('(?!\\\\n)\\\\s+')",
#                                   'prefix_re': 're.compile(\'^[\\\\[\\\\]\\\\("\\\'\\\\.,;:-]\')',
#                                   'remove_stopwords': [],
#                                   'simple_url_re': "re.compile('^https?://')",
#                                   'skip_entities': [ 'CARDINAL',
#                                                      'DATE (except months)',
#                                                      'QUANTITY',
#                                                      'TIME'],
#                                   'suffix_re': 're.compile(\'[\\\\[\\\\]\\\\)"\\\'\\\\.,;:-]$\')'},
#                       'description': 'English multi-task CNN trained on '
#                                      'OntoNotes. Assigns context-specific '
#                                      'token vectors, POS tags, dependency '
#                                      'parse and named entities.',
#                       'email': 'contact@explosion.ai',
#                       'lang': 'en',
#                       'license': 'MIT',
#                       'name': 'core_web_sm',
#                       'parent_package': 'spacy',
#                       'pipeline': [ 'tagger',
#                                     'parser',
#                                     'ner',
#                                     'skip_ents',
#                                     'readability'],
#                       'sources': ['OntoNotes 5'],
#                       'spacy_version': '>=2.1.0',
#                       'speed': { 'cpu': 6684.8046553827,
#                                  'gpu': None,
#                                  'nwords': 291314},
#                       'url': 'https://explosion.ai',
#                       'vectors': { 'keys': 0,
#                                    'name': None,
#                                    'vectors': 0,
#                                    'width': 0},
#                       'version': '2.1.0'},
#   'length': '850',
#   'metapath': 'Corpus,lexisnexis,144564_144564_bangordailynews_bodyliberalpre1pluralartsorhleadliberalpre1pluralarts_2004-01-01_2004-12-31_276_7_2',
#   'name': '144564_144564_bangordailynews_bodyliberalpre1pluralartsorhleadliberalpre1pluralarts_2004-01-01_2004-12-31_276_7_2',
#   'namespace': 'we1sv2.0',
#   'ppversion': '0.1',
#   'pub': 'Bangor Daily News (Maine)',
#   'pub_date': '2004-11-01T00:00:00Z',
#   'readability_scores': [ 97.70342465753426,
#                           0.43568706840317617,
#                           18.553588200583334],
#   'section': 'Pg. C2',
#   'sources': ['bangordailynews'],
#   'title': 'Cross country',
#   'word_count': 675}
# count: 0

# %%
def search_sources_tags(tag_term):
    hits = 0
    query = { 'tags': { '$regex' : tag_term } }
    client = MongoClient('mongodb://mongo/')
    results = client['Sources']['Sources'].find(query)
    for result in results:
        hits += 1
        pp.pprint(result)
        print('count:', hits)

# %%
search_sources_tags("education")
# Out:
# { '_id': '21st-century-principal',
#   'aliases': ['21st-century-principal'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': '21st-century-principal',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/South', 'media/website', 'education/perspective/K-12'],
#   'title': '21st Century Principal'}
# count: 1
# { '_id': 'accent-austin-community-college',
#   'aliases': ['Accent: Austin Community College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'accent-austin-community-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/institution/Community College'],
#   'title': 'Accent: Austin Community College'}
# count: 2
# { '_id': 'advance-titan-university-of-wisconsin-oshkosh',
#   'aliases': ['Advance-Titan: University of Wisconsin - Oshkosh'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'advance-titan-university-of-wisconsin-oshkosh',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/Midwest', 'education/funding/US public college'],
#   'title': 'Advance-Titan: University of Wisconsin - Oshkosh'}
# count: 3
# { '_id': 'american-school-and-university',
#   'aliases': ['americanschoolanduniversity'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'american-school-and-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/mulitregional',
#             'media/magazine',
#             'education/perspective/faculty and administration'],
#   'title': 'American School and University'}
# count: 4
# { '_id': 'anchor-rhode-island-college',
#   'aliases': ['Anchor: Rhode Island College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'anchor-rhode-island-college',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/North East', 'education/funding/US public college'],
#   'title': 'The Anchor'}
# count: 5
# { '_id': 'aquinas-times-aquinas-college',
#   'aliases': ['Aquinas Times'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'aquinas-times-aquinas-college',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/Midwest', 'education/demographic/religion/Catholic'],
#   'title': 'Aquinas Times'}
# count: 6
# { '_id': 'arches-mount-mary-college',
#   'aliases': ['Arches: Mount Mary College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'arches-mount-mary-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US private college',
#             'education/demographic/religion/Catholic',
#             'education/demographic/Womens College'],
#   'title': 'Arches: Mount Mary College'}
# count: 7
# { '_id': 'arizona-daily-wildcat-university-of-arizona',
#   'aliases': ['Arizona Daily Wildcat: University of Arizona'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'arizona-daily-wildcat-university-of-arizona',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Rockies and Southwest',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/institution/Doctoral'],
#   'title': 'Arizona Daily Wildcat'}
# count: 8
# { '_id': 'arka-tech-arkansas-tech',
#   'aliases': ['Arka Tech: Arkansas Tech'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'arka-tech-arkansas-tech',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/emphasis/Science Tech and Ag school',
#             'education/institution/Doctoral'],
#   'title': 'Arka Tech: Arkansas Tech'}
# count: 9
# { '_id': 'arkansas-traveler-university-of-arkansas',
#   'aliases': ['Arkansas Traveler: University of Arkansas'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'arkansas-traveler-university-of-arkansas',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Arkansas Traveler'}
# count: 10
# { '_id': 'asu-west-express',
#   'aliases': ['ASU West Express'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'asu-west-express',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Rockies and Southwest',
#             'education/institution/Doctoral',
#             'education/funding/US public college'],
#   'title': 'ASU West Express'}
# count: 11
# { '_id': 'austin-college-observer-austin-college',
#   'aliases': ['Austin College Observer: Austin College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'austin-college-observer-austin-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US private college',
#             'education/demographic/religion/Christian',
#             'education/institution/Liberal Arts'],
#   'title': 'Austin College Observer: Austin College'}
# count: 12
# { '_id': 'aztec-press-pima-community-college',
#   'aliases': ['Aztec Press: Pima Community College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'aztec-press-pima-community-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/institution/Community College'],
#   'title': 'Aztec Press: Pima Community College'}
# count: 13
# { '_id': 'badger-herald-university-of-wisconsin-madison',
#   'aliases': ['Badger Herald: University of Wisconsin - Madison'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'badger-herald-university-of-wisconsin-madison',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Badger Herald: University of Wisconsin - Madison'}
# count: 14
# { '_id': 'barnard-bulletin-barnard-college',
#   'aliases': ['Barnard Bulletin: Barnard College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'barnard-bulletin-barnard-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/demographic/Womens College',
#             'education/institution/Liberal Arts'],
#   'title': 'Barnard Bulletin: Barnard College'}
# count: 15
# { '_id': 'black-and-magenta-muskingum-college',
#   'aliases': ['Black and Magenta: Muskingum College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'black-and-magenta-muskingum-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US private college',
#             'education/institution/Liberal Arts'],
#   'title': 'Black and Magenta: Muskingum College'}
# count: 16
# { '_id': 'black-squirrel-radio-kent-state-university',
#   'aliases': ['Black Squirrel Radio: Kent State University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'black-squirrel-radio-kent-state-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US public college',
#             'media/radio',
#             'education/institution/Doctoral'],
#   'title': 'Black Squirrel Radio: Kent State University'}
# count: 17
# { '_id': 'bowdoin-orient',
#   'aliases': ['Bowdoin Orient'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'bowdoin-orient',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/institution/Liberal Arts'],
#   'title': 'Bowdoin Orient'}
# count: 18
# { '_id': 'brock-press-brock-university',
#   'aliases': ['The Brock Press'],
#   'country': 'CA',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'brock-press-brock-university',
#   'namespace': 'we1s2.0',
#   'tags': ['region/Canada', 'education/non-US college'],
#   'title': 'Brock Press: Brock University'}
# count: 19
# { '_id': 'brookhaven-courier-brookhaven-college',
#   'aliases': ['Brookhaven Courier: Brookhaven College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'brookhaven-courier-brookhaven-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/institution/Community College'],
#   'title': 'Brookhaven Courier: Brookhaven College'}
# count: 20
# { '_id': 'buccaneer-peninsula-college',
#   'aliases': ['Buccaneer: Peninsula College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'buccaneer-peninsula-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/West Coast',
#             'education/funding/US public college',
#             'education/institution/Community College'],
#   'title': 'Buccaneer: Peninsula College'}
# count: 21
# { '_id': 'cable-college-of-st-scholastica',
#   'aliases': ['Cable: College of St. Scholastica'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'cable-college-of-st-scholastica',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/demographic/religion/Catholic',
#             'education/funding/US private college',
#             'education/institution/Liberal Arts'],
#   'title': 'Cable: College of St. Scholastica'}
# count: 22
# { '_id': 'calvin-college-chimes-calvin-college',
#   'aliases': ['Calvin College Chimes: Calvin College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'calvin-college-chimes-calvin-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US private college',
#             'education/demographic/religion/Christian',
#             'education/institution/Liberal Arts'],
#   'title': 'Calvin College Chimes: Calvin College'}
# count: 23
# { '_id': 'cameron-collegian-cameron-university',
#   'aliases': ['Cameron Collegian: Cameron University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'cameron-collegian-cameron-university',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/South', 'education/funding/US public college'],
#   'title': 'Cameron Collegian: Cameron University'}
# count: 24
# { '_id': 'campus-carrier-berry-college',
#   'aliases': ['Campus Carrier: Berry College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'campus-carrier-berry-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US private college',
#             'education/institution/Liberal Arts'],
#   'title': 'Campus Carrier: Berry College'}
# count: 25
# { '_id': 'campus-echo-north-carolina-central-university',
#   'aliases': ['Campus Echo: North Carolina Central University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'campus-echo-north-carolina-central-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/demographic/Historically Black Colleges and '
#             'Universities'],
#   'title': 'Campus Echo: North Carolina Central University'}
# count: 26
# { '_id': 'campus-press-university-of-colorado-boulder',
#   'aliases': ['Campus Press: University of Colorado at Boulder'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'campus-press-university-of-colorado-boulder',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Rockies and Southwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Campus Press: University of Colorado at Boulder'}
# count: 27
# { '_id': 'campus-times-university-of-rochester',
#   'aliases': ['Campus Times: University of Rochester'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'campus-times-university-of-rochester',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/institution/Doctoral'],
#   'title': 'Campus Times: University of Rochester'}
# count: 28
# { '_id': 'cardinal-and-cream-union-university',
#   'aliases': ['Cardinal and Cream: Union University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'cardinal-and-cream-union-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US private college',
#             'education/demographic/religion/Christian',
#             'education/institution/Liberal Arts'],
#   'title': 'Cardinal and Cream: Union University'}
# count: 29
# { '_id': 'cardinal-points-suny-plattsburgh',
#   'aliases': ['Cardinal Points: SUNY College at Plattsburgh'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'cardinal-points-suny-plattsburgh',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/North East', 'education/funding/US public college'],
#   'title': 'Cardinal Points: SUNY College at Plattsburgh'}
# count: 30
# { '_id': 'carson-newman-carson-newman-college',
#   'aliases': ['Carson-Newman: Carson-Newman College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'carson-newman-carson-newman-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US private college',
#             'education/demographic/religion/Christian',
#             'education/institution/Liberal Arts'],
#   'title': 'Carson-Newman: Carson-Newman College'}
# count: 31
# { '_id': 'cavalier-daily-university-of-virginia',
#   'aliases': ['Cavalier Daily: University of Virginia'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'cavalier-daily-university-of-virginia',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Cavalier Daily: University of Virginia'}
# count: 32
# { '_id': 'central-florida-future-university-of-central-florida',
#   'aliases': ['Central Florida Future: University of Central Florida'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'central-florida-future-university-of-central-florida',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/institution/Doctoral'],
#   'title': 'Central Florida Future: University of Central Florida'}
# count: 33
# { '_id': 'chicago-maroon-university-of-chicago',
#   'aliases': ['Chicago Maroon: University of Chicago'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'chicago-maroon-university-of-chicago',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US private college',
#             'education/institution/Doctoral'],
#   'title': 'Chicago Maroon: University of Chicago'}
# count: 34
# { '_id': 'chips-luther-college',
#   'aliases': ['Chips: Luther College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'chips-luther-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US private college',
#             'education/demographic/religion/Christian',
#             'education/institution/Liberal Arts'],
#   'title': 'Chips: Luther College'}
# count: 35
# { '_id': 'chronicle-higher-ed',
#   'aliases': ['chronicleofhighereducation'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'chronicle-higher-ed',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/mulitregional',
#             'media/US newspaper',
#             'education/perspective/faculty and administration'],
#   'title': 'The Chronicle of Higher Education'}
# count: 36
# { '_id': 'city-college-news-minneapolis-community-and-technical-college',
#   'aliases': ['City College News: Minneapolis Community & Technical College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'city-college-news-minneapolis-community-and-technical-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US public college',
#             'education/emphasis/Science Tech and Ag school',
#             'education/institution/Community College'],
#   'title': 'City College News: Minneapolis Community & Technical College'}
# count: 37
# { '_id': 'city-times-san-diego-city-college',
#   'aliases': ['City Times: San Diego City College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'city-times-san-diego-city-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/West Coast',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/institution/Community College'],
#   'title': 'City Times: San Diego City College'}
# count: 38
# { '_id': 'claflin-panther-claflin-university',
#   'aliases': ['Claflin Panther: Claflin University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'claflin-panther-claflin-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US private college',
#             'education/demographic/Historically Black Colleges and '
#             'Universities'],
#   'title': 'Claflin Panther: Claflin University'}
# count: 39
# { '_id': 'college-board',
#   'aliases': ['college-board'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'college-board',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/mulitregional',
#             'media/website',
#             'education/perspective/professional organizations'],
#   'title': 'College Board'}
# count: 40
# { '_id': 'college-heights-herald-western-kentucky-university',
#   'aliases': ['College Heights Herald: Western Kentucky University\\xa0'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'college-heights-herald-western-kentucky-university',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/South', 'education/funding/US public college'],
#   'title': 'College Heights Herald: Western Kentucky University'}
# count: 41
# { '_id': 'college-media-network',
#   'aliases': ['College Media Network: Media network college'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'college-media-network',
#   'namespace': 'we1s2.0',
#   'tags': ['education/'],
#   'title': 'College Media Network: Media network college'}
# count: 42
# { '_id': 'college-standard-magazine',
#   'aliases': ['College Standard Magazine'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'college-standard-magazine',
#   'namespace': 'we1s2.0',
#   'tags': ['education/'],
#   'title': 'College Standard Magazine'}
# count: 43
# { '_id': 'collegian-delta-college',
#   'aliases': ['Collegian: Delta College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'collegian-delta-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/West Coast',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/institution/Community College'],
#   'title': 'Collegian: Delta College'}
# count: 44
# { '_id': 'collegiate-grand-rapids-community-college',
#   'aliases': ['Collegiate: Grand Rapids Community College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'collegiate-grand-rapids-community-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US public college',
#             'education/institution/Community College'],
#   'title': 'Collegiate: Grand Rapids Community College'}
# count: 45
# { '_id': 'colorado-daily-university-of-colorado-boulder',
#   'aliases': ['Colorado Daily: University of Colorado at Boulder'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'colorado-daily-university-of-colorado-boulder',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Rockies and Southwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Colorado Daily: University of Colorado at Boulder'}
# count: 46
# { '_id': 'commonwealth-times-virginia-commonwealth-university',
#   'aliases': ['Commonwealth Times: Virginia Commonwealth University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'commonwealth-times-virginia-commonwealth-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Commonwealth Times: Virginia Commonwealth University'}
# count: 47
# { '_id': 'concordiensis-union-college',
#   'aliases': ['Concordiensis: Union College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'concordiensis-union-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/institution/Liberal Arts'],
#   'title': 'Concordiensis: Union College'}
# count: 48
# { '_id': 'connect2mason-george-mason-university',
#   'aliases': ['Connect2Mason: George Mason University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'connect2mason-george-mason-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Connect2Mason: George Mason University'}
# count: 49
# { '_id': 'cornell-daily-sun-cornell-university',
#   'aliases': ['Cornell Daily Sun: Cornell University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'cornell-daily-sun-cornell-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/affiliation/Ivy League',
#             'education/institution/Doctoral'],
#   'title': 'Cornell Daily Sun: Cornell University'}
# count: 50
# { '_id': 'counterpoint-massachusetts-institute-of-technology-wellesley-college',
#   'aliases': [ 'Counterpint: Massachusetts Institute of Technology - Wellesley '
#                'College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'counterpoint-massachusetts-institute-of-technology-wellesley-college',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/North East', 'education/funding/US private college'],
#   'title': 'Counterpoint: Massachusetts Institute of Technology - Wellesley '
#            'College'}
# count: 51
# { '_id': 'crimson-florida-technical-college',
#   'aliases': ['Crimson: Florida Technical College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'crimson-florida-technical-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US private college',
#             'education/emphasis/Science Tech and Ag school'],
#   'title': 'Crimson: Florida Technical College'}
# count: 52
# { '_id': 'cw-post-pioneer-long-island-university-cw-post-campus',
#   'aliases': ['CW Post Pioneer: Long Island University - C W Post Campus'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'cw-post-pioneer-long-island-university-cw-post-campus',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/institution/Liberal Arts'],
#   'title': 'CW Post Pioneer: Long Island University'}
# count: 53
# { '_id': 'daily-49er-california-state-university-long-beach',
#   'aliases': ['Daily Forty-Niner'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-49er-california-state-university-long-beach',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/West Coast',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/affiliation/Cal State system'],
#   'title': 'Daily 49er: California State University-Long Beach'}
# count: 54
# { '_id': 'daily-bruin-university-of-california-los-angeles',
#   'aliases': ['Daily Bruin: University of California-Los Angeles'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-bruin-university-of-california-los-angeles',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/West Coast',
#             'education/funding/US public college',
#             'education/affiliation/UC system',
#             'education/institution/Doctoral'],
#   'title': 'Daily Bruin'}
# count: 55
# { '_id': 'daily-californian-university-of-california-berkeley',
#   'aliases': ['Daily Californian: University of California-Berkeley'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-californian-university-of-california-berkeley',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/West Coast',
#             'education/funding/US public college',
#             'education/affiliation/UC system',
#             'education/institution/Doctoral'],
#   'title': 'Daily Californian'}
# count: 56
# { '_id': 'daily-collegian-pennsylvania-state-university',
#   'aliases': ['Daily Collegian: Pennsylvania State University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-collegian-pennsylvania-state-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Daily Collegian: Pennsylvania State University'}
# count: 57
# { '_id': 'daily-eastern-news-eastern-illinois-university',
#   'aliases': ['Daily Eastern News: Eastern Illinois University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-eastern-news-eastern-illinois-university',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/Midwest', 'education/funding/US public college'],
#   'title': 'Daily Eastern News: Eastern Illinois University'}
# count: 58
# { '_id': 'daily-evergreen-washington-state-university',
#   'aliases': ['Daily Evergreen: Washington State University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-evergreen-washington-state-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/West Coast',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Daily Evergreen: Washington State University'}
# count: 59
# { '_id': 'daily-illini-university-of-illinois-at-urbana-champaign',
#   'aliases': ['Daily Illini: University of Illinois at Urbana-Champaign'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-illini-university-of-illinois-at-urbana-champaign',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Daily Illini: University of Illinois at Urbana-Champaign'}
# count: 60
# { '_id': 'daily-lobo-university-of-new-mexico',
#   'aliases': ['Daily Lobo: University of New Mexico'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-lobo-university-of-new-mexico',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Rockies and Southwest',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/institution/Doctoral'],
#   'title': 'Daily Lobo: University of New Mexico'}
# count: 61
# { '_id': 'daily-mississippian-university-of-mississippi',
#   'aliases': ['Daily Mississippian: University of Mississippi'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-mississippian-university-of-mississippi',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Daily Mississippian: University of Mississippi'}
# count: 62
# { '_id': 'daily-nebraskan-university-of-nebraska-lincoln',
#   'aliases': ['Daily Nebraskan: University of Nebraska-Lincoln'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-nebraskan-university-of-nebraska-lincoln',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Daily Nebraskan: University of Nebraska-Lincoln'}
# count: 63
# { '_id': 'daily-nexus',
#   'aliases': ['daily-nexus'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-nexus',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/West Coast',
#             'media/US newspaper',
#             'education/perspective/students',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/affiliation/UC system'],
#   'title': 'Daily Nexus'}
# count: 64
# { '_id': 'daily-northwestern-northwestern-university',
#   'aliases': ['Daily Northwestern: Northwestern University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-northwestern-northwestern-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US private college',
#             'education/institution/Doctoral'],
#   'title': 'Daily Northwestern: Northwestern University'}
# count: 65
# { '_id': 'daily-o-collegian-oklahoma-state-university',
#   'aliases': ["Daily O\\\\'Collegian: Oklahoma State University"],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-o-collegian-oklahoma-state-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': "Daily O'Collegian: Oklahoma State University"}
# count: 66
# { '_id': 'daily-orange-syracuse-university',
#   'aliases': ['Daily Orange'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-orange-syracuse-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/institution/Doctoral'],
#   'title': 'Daily Orange'}
# count: 67
# { '_id': 'daily-pennsylvanian-university-of-pennsylvania',
#   'aliases': ['Daily Pennsylvanian'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-pennsylvanian-university-of-pennsylvania',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/affiliation/Ivy League',
#             'education/institution/Doctoral'],
#   'title': 'Daily Pennsylvanian'}
# count: 68
# { '_id': 'daily-skiff-texas-christian-university',
#   'aliases': ['Daily Skiff: Texas Christian University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-skiff-texas-christian-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US private college',
#             'education/demographic/religion/Christian',
#             'education/institution/Doctoral'],
#   'title': 'Daily Skiff: Texas Christian University'}
# count: 69
# { '_id': 'daily-targum-rutgers-university',
#   'aliases': ['Daily Targum: Rutgers University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-targum-rutgers-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Daily Targum: Rutgers University'}
# count: 70
# { '_id': 'daily-trojan-university-of-southern-california',
#   'aliases': ['Daily Trojan: University of Southern California'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'daily-trojan-university-of-southern-california',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/West Coast',
#             'education/funding/US private college',
#             'education/institution/Doctoral'],
#   'title': 'Daily Trojan: University of Southern California'}
# count: 71
# { '_id': 'dakota-student-university-of-north-dakota',
#   'aliases': ['Dakota Student: University of North Dakota'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'dakota-student-university-of-north-dakota',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Dakota Student: University of North Dakota'}
# count: 72
# { '_id': 'dominican-star-dominican-university',
#   'aliases': ['Dominican Star: Dominican University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'dominican-star-dominican-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US private college',
#             'education/demographic/religion/Catholic',
#             'education/demographic/Hispanic-serving Institution'],
#   'title': 'Dominican Star: Dominican University'}
# count: 73
# { '_id': 'driftwood-university-of-new-orleans',
#   'aliases': ['Driftwood: University of New Orleans'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'driftwood-university-of-new-orleans',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Driftwood: University of New Orleans'}
# count: 74
# { '_id': 'eagle-robert-morris-college',
#   'aliases': ['Eagle: Robert Morris College', 'Eagle: Robert Morris College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'eagle-robert-morris-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/demographic/Hispanic-serving Institution',
#             'education/funding/US private college'],
#   'title': 'Eagle: Robert Morris College'}
# count: 75
# { '_id': 'east-carolinian-east-carolina-university',
#   'aliases': ['East Carolinian: East Carolina University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'east-carolinian-east-carolina-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'East Carolinian: East Carolina University'}
# count: 76
# { '_id': 'east-tennessean-east-tennessee-state-university',
#   'aliases': ['East Tennessean: East Tennessee State University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'east-tennessean-east-tennessee-state-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'East Tennessean: East Tennessee State University'}
# count: 77
# { '_id': 'education-next',
#   'aliases': ['education-next'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'education-next',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/mulitregional',
#             'media/magazine',
#             'education/perspective/K-12'],
#   'title': 'Education Next'}
# count: 78
# { '_id': 'education-week',
#   'aliases': ['educationweek'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'education-week',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/mulitregional',
#             'media/US newspaper',
#             'education/perspective/K-12'],
#   'title': 'Education Week'}
# count: 79
# { '_id': 'el-vaquero-glendale-community-college',
#   'aliases': [ 'El Vaquero: Glendale Community College',
#                'El Vaquero: Glendale Community College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'el-vaquero-glendale-community-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/West Coast',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/institution/Community College'],
#   'title': 'El Vaquero: Glendale Community College'}
# count: 80
# { '_id': 'emory-wheel-emory-university',
#   'aliases': ['Emory Wheel: Emory University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'emory-wheel-emory-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US private college',
#             'education/institution/Doctoral'],
#   'title': 'Emory Wheel: Emory University'}
# count: 81
# { '_id': 'endicott-observer-endicott-college',
#   'aliases': ['Endicott Observer: Endicott College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'endicott-observer-endicott-college',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/North East', 'education/funding/US private college'],
#   'title': 'Endicott Observer: Endicott College'}
# count: 82
# { '_id': 'et-cetera-eastfield-college',
#   'aliases': ['Et Cetera: Eastfield College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'et-cetera-eastfield-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/institution/Community College'],
#   'title': 'Et Cetera: Eastfield College'}
# count: 83
# { '_id': 'exponent-montana-state-university',
#   'aliases': ['Exponent: Montana State University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'exponent-montana-state-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Rockies and Southwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Exponent: Montana State University'}
# count: 84
# { '_id': 'factory-times-suny-institute-of-technology-utica-rome',
#   'aliases': ['Factory Times: SUNY Institute of Technology at Utica-Rome'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'factory-times-suny-institute-of-technology-utica-rome',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US public college',
#             'education/emphasis/Science Tech and Ag school'],
#   'title': 'Factory Times: SUNY Institute of Technology at Utica - Rome'}
# count: 85
# { '_id': 'fiat-lux-alfred-university',
#   'aliases': ['Flat Lux: Alfred University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'fiat-lux-alfred-university',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/North East', 'education/funding/US private college'],
#   'title': 'Flat Lux: Alfred University'}
# count: 86
# { '_id': 'flat-hat-college-of-william-and-mary',
#   'aliases': ['Flat Hat: College of William and Mary'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'flat-hat-college-of-william-and-mary',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Flat Hat: College of William and Mary'}
# count: 87
# { '_id': 'foghorn-del-mar-college',
#   'aliases': ['Foghorn: Del Mar College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'foghorn-del-mar-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/institution/Community College'],
#   'title': 'Foghorn: Del Mar College'}
# count: 88
# { '_id': 'fsview-and-florida-flambeau-florida-state-university',
#   'aliases': ['FSView & Florida Flambeau: Florida State University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'fsview-and-florida-flambeau-florida-state-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'FSView & Florida Flambeau: Florida State University'}
# count: 89
# { '_id': 'gannon-knight-gannon-university',
#   'aliases': ['Gannon Knight: Gannon University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'gannon-knight-gannon-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/demographic/religion/Catholic'],
#   'title': 'Gannon Knight: Gannon University'}
# count: 90
# { '_id': 'gator-times-university-of-florida',
#   'aliases': ['Gator Times: University of Florida'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'gator-times-university-of-florida',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Gator Times: University of Florida'}
# count: 91
# { '_id': 'golden-gate-xpress-san-francisco-state-university',
#   'aliases': ['Golden Gate Xpress: San Francisco State University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'golden-gate-xpress-san-francisco-state-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/West Coast',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/affiliation/Cal State system'],
#   'title': 'Golden Gate Xpress: San Francisco State University'}
# count: 92
# { '_id': 'h-net',
#   'aliases': ['h-net'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'h-net',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/mulitregional',
#             'media/website',
#             'education/perspective/faculty and administration'],
#   'title': 'H-Net'}
# count: 93
# { '_id': 'hampden-sydney-tiger-hampden-sydney-college',
#   'aliases': ['Hampden-Sydney Tiger: Hampden-Sydney College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'hampden-sydney-tiger-hampden-sydney-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US private college',
#             'education/institution/Liberal Arts'],
#   'title': 'Hampden-Sydney Tiger: Hampden-Sydney College'}
# count: 94
# { '_id': 'harbinger-illinois-central-college',
#   'aliases': ['Harbinger: Illinois Central College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'harbinger-illinois-central-college',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/Midwest', 'education/institution/Community College'],
#   'title': 'Harbinger: Illinois Central College'}
# count: 95
# { '_id': 'harvard-political-review-harvard-university',
#   'aliases': ['Harvard Political Review: Harvard University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'harvard-political-review-harvard-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/affiliation/Ivy League',
#             'education/institution/Doctoral'],
#   'title': 'Harvard Political Review: Harvard University'}
# count: 96
# { '_id': 'her-campus',
#   'aliases': ['her-campus'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'her-campus',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/mulitregional',
#             'media/magazine',
#             'identity/gender and sexuality',
#             'education/perspective/students'],
#   'title': 'Her Campus'}
# count: 97
# { '_id': 'herald-arkansas-state-university',
#   'aliases': ['Herald: Arkansas State University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'herald-arkansas-state-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Herald: Arkansas State University'}
# count: 98
# { '_id': 'highland-cavalier-university-of-virginia-wise',
#   'aliases': ['Highland Cavalier: University of Virginia - Wise'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'highland-cavalier-university-of-virginia-wise',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Liberal Arts'],
#   'title': 'Highland Cavalier: University of Virginia - Wise'}
# count: 99
# { '_id': 'hilltop-howard-university',
#   'aliases': ['Hilltop: Howard University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'hilltop-howard-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/demographic/Historically Black Colleges and '
#             'Universities',
#             'education/institution/Doctoral'],
#   'title': 'Hilltop: Howard University'}
# count: 100
# { '_id': 'hilltop-news-st-edwards-university',
#   'aliases': ["Hilltop News: St. Edward's University"],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'hilltop-news-st-edwards-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US private college',
#             'education/demographic/religion/Catholic',
#             'education/demographic/Hispanic-serving Institution',
#             'education/institution/Liberal Arts'],
#   'title': "Hilltop News: St. Edward's University"}
# count: 101
# { '_id': 'hilltops-hartwick-college',
#   'aliases': ['Hilltops: Hartwick College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'hilltops-hartwick-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/institution/Liberal Arts'],
#   'title': 'Hilltops: Hartwick College'}
# count: 102
# { '_id': 'horizons-embry-riddle-aeronautical-university',
#   'aliases': [ 'Horizons: Embry-Riddle Aeronautical University',
#                'Horizons: Embry-Riddle Aeronautical University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'horizons-embry-riddle-aeronautical-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Rockies and Southwest',
#             'education/funding/US private college',
#             'education/emphasis/Science Tech and Ag school'],
#   'title': 'Horizons: Embry-Riddle Aeronautical University'}
# count: 103
# { '_id': 'houstonian-sam-houston-state-university',
#   'aliases': ['The Houstonian'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'houstonian-sam-houston-state-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Houstonian: Sam Houston State University'}
# count: 104
# { '_id': 'idaho-argonaut-university-of-idaho',
#   'aliases': ['Idaho Argonaut: University of Idaho'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'idaho-argonaut-university-of-idaho',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Rockies and Southwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Idaho Argonaut: University of Idaho'}
# count: 105
# { '_id': 'independent-collegian-university-of-toledo',
#   'aliases': ['Independent Collegian: University of Toledo\\xa0'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'independent-collegian-university-of-toledo',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Independent Collegian: University of Toledo'}
# count: 106
# { '_id': 'independent-florida-alligator-university-of-florida',
#   'aliases': ['Independent Florida Alligator: University of Florida'],
# ...
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'the-voice-glendale-community-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Rockies and Southwest',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/institution/Community College'],
#   'title': 'The Voice: Glendale Community College'}
# count: 602
# { '_id': 'the-volunteer-john-a-logan-college',
#   'aliases': ['The Volunteer: John A. Logan College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'the-volunteer-john-a-logan-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US public college',
#             'education/institution/Community College'],
#   'title': 'The Volunteer: John A. Logan College'}
# count: 603
# { '_id': 'the-voyager-university-of-west-florida',
#   'aliases': ['The Voyager: University of West Florida'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'the-voyager-university-of-west-florida',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/South', 'education/funding/US public college'],
#   'title': 'The Voyager: University of West Florida'}
# count: 604
# { '_id': 'the-washburn-review-washburn-university',
#   'aliases': ['The Washburn Review: Washburn University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'the-washburn-review-washburn-university',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/Midwest', 'education/funding/US public college'],
#   'title': 'The Washburn Review: Washburn University'}
# count: 605
# { '_id': 'the-washington-daily',
#   'aliases': ['The Washington Daily'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'the-washington-daily',
#   'namespace': 'we1s2.0',
#   'tags': ['education/'],
#   'title': 'The Washington Daily'}
# count: 606
# { '_id': 'the-wesleyan-argus-wesleyan-university',
#   'aliases': ['The Wesleyan Argus: Wesleyan University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'the-wesleyan-argus-wesleyan-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/institution/Liberal Arts'],
#   'title': 'The Wesleyan Argus: Wesleyan University'}
# count: 607
# { '_id': 'the-whit-rowan-university',
#   'aliases': ['The Whit: Rowan University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'the-whit-rowan-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': ''}
# count: 608
# { '_id': 'the-whitman-college-pioneer-whitman-college',
#   'aliases': ['The Whitman College Pioneer: Whitman College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'the-whitman-college-pioneer-whitman-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/West Coast',
#             'education/funding/US private college',
#             'education/institution/Liberal Arts'],
#   'title': 'The Whitman College Pioneer: Whitman College'}
# count: 609
# { '_id': 'the-word-hunter-college',
#   'aliases': ['The WORD: Hunter College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'the-word-hunter-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution'],
#   'title': 'The WORD: Hunter College'}
# count: 610
# { '_id': 'the-yale-herald-yale-university',
#   'aliases': ['The Yale Herald: Yale University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'the-yale-herald-yale-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/affiliation/Ivy League',
#             'education/institution/Doctoral'],
#   'title': 'The Yale Herald: Yale University'}
# count: 611
# { '_id': 'tufts-daily-tufts-university',
#   'aliases': ['Tufts Daily: Tufts University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'tufts-daily-tufts-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/institution/Doctoral'],
#   'title': 'Tufts Daily: Tufts University'}
# count: 612
# { '_id': 'u-loop-com',
#   'aliases': ['Uloop.com'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'u-loop-com',
#   'namespace': 'we1s2.0',
#   'tags': ['education/', 'media/website'],
#   'title': 'Uloop.com'}
# count: 613
# { '_id': 'uc-denver-advocate',
#   'aliases': ['UCD Advocate: University of Colorado Denver'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'uc-denver-advocate',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Rockies and Southwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'UCD Advocate: University of Colorado Denver'}
# count: 614
# { '_id': 'uhclidian',
#   'aliases': ['UHCLIDIAN'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'uhclidian',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'UHCLIDIAN'}
# count: 615
# { '_id': 'uic-today',
#   'aliases': ['UIC Today'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'uic-today',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'UIC Today'}
# count: 616
# { '_id': 'umd-statesman-university-of-minnesota-duluth',
#   'aliases': ['UMD Statesman: University of Minnesota-Duluth'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'umd-statesman-university-of-minnesota-duluth',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/Midwest', 'education/funding/US public college'],
#   'title': 'UMD Statesman: University of Minnesota-Duluth'}
# count: 617
# { '_id': 'unc-mirror-university-of-northern-colorado',
#   'aliases': ['UNC Mirror: University of Northern Colorado'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'unc-mirror-university-of-northern-colorado',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Rockies and Southwest',
#             'education/funding/US public college'],
#   'title': 'UNC Mirror: University of Northern Colorado'}
# count: 618
# { '_id': 'university-chronicle-st-cloud-state-university',
#   'aliases': ['University Chronicle: St Cloud State University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'university-chronicle-st-cloud-state-university',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/Midwest', 'education/funding/US public college'],
#   'title': 'University Chronicle: St Cloud State University'}
# count: 619
# { '_id': 'university-daily-kansan-university-of-kansas',
#   'aliases': ['University Daily Kansan'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'university-daily-kansan-university-of-kansas',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'University Daily Kansan'}
# count: 620
# { '_id': 'university-news-university-of-missouri-kansas-city',
#   'aliases': ['University News: University of Missouri-Kansas City'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'university-news-university-of-missouri-kansas-city',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'University News: University of Missouri - Kansas City'}
# count: 621
# { '_id': 'university-press-lamar-university',
#   'aliases': ['University Press: Lamar University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'university-press-lamar-university',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/South', 'education/funding/US public college'],
#   'title': 'University Press: Lamar University'}
# count: 622
# { '_id': 'university-times-california-state-university-los-angeles',
#   'aliases': ['University Times: California State University-Los Angeles'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'university-times-california-state-university-los-angeles',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/West Coast',
#             'education/funding/US public college',
#             'education/demographic/Hispanic-serving Institution',
#             'education/affiliation/Cal State system',
#             'education/institution/Doctoral'],
#   'title': 'University Times: California State University-Los Angeles'}
# count: 623
# { '_id': 'university-wire',
#   'aliases': ['U-WIRE'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'university-wire',
#   'namespace': 'we1s2.0',
#   'tags': [ 'media/news wires and aggregators',
#             'media/US newspaper',
#             'education/perspective/students'],
#   'title': 'University Wire'}
# count: 624
# { '_id': 'utvs-6-television-st-cloud-state-university',
#   'aliases': ['UTVS 6 Television: St Cloud State University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'utvs-6-television-st-cloud-state-university',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/Midwest', 'education/funding/US public college'],
#   'title': 'UTVS 6 Television: St Cloud State University'}
# count: 625
# { '_id': 'uwm-post',
#   'aliases': ['UWM Post'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'uwm-post',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'UWM Post'}
# count: 626
# { '_id': 'vanderbilt-hustler',
#   'aliases': ['Vanderbilt Hustler'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'vanderbilt-hustler',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/South',
#             'education/funding/US private college',
#             'education/institution/Doctoral'],
#   'title': 'Vanderbilt Hustler'}
# count: 627
# { '_id': 'vermont-cynic-university-of-vermont',
#   'aliases': ['Vermont Cynic: University of Vermont'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'vermont-cynic-university-of-vermont',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US public college',
#             'education/institution/Doctoral'],
#   'title': 'Vermont Cynic: University of Vermont'}
# count: 628
# { '_id': 'voice',
#   'aliases': ['The Voice'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'voice',
#   'namespace': 'we1s2.0',
#   'tags': ['education/'],
#   'title': 'The Voice'}
# count: 629
# { '_id': 'volante',
#   'aliases': ['Volante'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'volante',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/Midwest', 'education/funding/US public college'],
#   'title': 'Volante'}
# count: 630
# { '_id': 'wartburg-trumpet-wartburg-college',
#   'aliases': ['Wartburg Trumpet: Wartburg College'],
#   'country': 'CR',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'wartburg-trumpet-wartburg-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US private college',
#             'education/demographic/religion/Christian',
#             'education/institution/Liberal Arts'],
#   'title': 'Wartburg Trumpet: Wartburg College'}
# count: 631
# { '_id': 'washington-square-news-new-york-university',
#   'aliases': ['Washington Square News: New York University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'washington-square-news-new-york-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/institution/Doctoral'],
#   'title': 'Washington Square News: New York University'}
# count: 632
# { '_id': 'wcn-westminster-college',
#   'aliases': ['WCN: Westminster College'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'wcn-westminster-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/institution/Liberal Arts'],
#   'title': 'WCN: Westminster College'}
# count: 633
# { '_id': 'wellesley-news-wellesley-college',
#   'aliases': ['Wellesley News: Wellesley College'],
#   'country': 'NG',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'wellesley-news-wellesley-college',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/demographic/Womens College',
#             'education/institution/Liberal Arts'],
#   'title': 'Wellesley News: Wellesley College'}
# count: 634
# { '_id': 'western-courier-western-illinois-university',
#   'aliases': ['Western Courier: Western Illinois University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'western-courier-western-illinois-university',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/Midwest', 'education/funding/US public college'],
#   'title': 'Western Courier: Western Illinois University'}
# count: 635
# { '_id': 'western-oregon-journal-western-oregon-university',
#   'aliases': ['Western Oregon Journal: Western Oregon University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'western-oregon-journal-western-oregon-university',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/West Coast', 'education/funding/US public college'],
#   'title': 'Western Oregon Journal: Western Oregon University'}
# count: 636
# { '_id': 'wuev-fm-university-of-evansville',
#   'aliases': ['WUEV-FM: University of Evansville'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'wuev-fm-university-of-evansville',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'education/funding/US private college',
#             'education/institution/Liberal Arts'],
#   'title': 'WUEV-FM: University of Evansville'}
# count: 637
# { '_id': 'wutm-fm-university-of-tennessee-martin',
#   'aliases': ['WUTM-FM: University of Tennessee - Martin'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'wutm-fm-university-of-tennessee-martin',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/South', 'education/funding/US public college'],
#   'title': 'WUTM-FM: University of Tennessee - Martin'}
# count: 638
# { '_id': 'wxou-883-fm-oakland-university',
#   'aliases': ['WXOU 88.3 FM: Oakland University'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'wxou-883-fm-oakland-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/Midwest',
#             'media/academic',
#             'education/institution/Doctoral'],
#   'title': 'WXOU 88.3 FM: Oakland University'}
# count: 639
# { '_id': 'wyoming-independent',
#   'aliases': ['Wyoming Independent'],
#   'country': 'US',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'wyoming-independent',
#   'namespace': 'we1s2.0',
#   'tags': ['region/US/Midwest', 'media/academic', 'education/'],
#   'title': 'Wyoming Independent'}
# count: 640
# { '_id': 'yale-daily-news-yale-university',
#   'aliases': ['Yale Daily News'],
#   'country': 'CN',
#   'language': 'en',
#   'metapath': 'Sources',
#   'name': 'yale-daily-news-yale-university',
#   'namespace': 'we1s2.0',
#   'tags': [ 'region/US/North East',
#             'education/funding/US private college',
#             'education/affiliation/Ivy League',
#             'education/institution/Doctoral'],
#   'title': 'Yale Daily News'}
# count: 641

# %% [markdown]
# ## Information

# %%
# retrieve the build information
client['we1s'].command("buildinfo")
# Out:
# {'version': '4.0.11',
#  'gitVersion': '417d1a712e9f040d54beca8e4943edce218e9a8c',
#  'modules': [],
#  'allocator': 'tcmalloc',
#  'javascriptEngine': 'mozjs',
#  'sysInfo': 'deprecated',
#  'versionArray': [4, 0, 11, 0],
#  'openssl': {'running': 'OpenSSL 1.0.2g  1 Mar 2016',
#   'compiled': 'OpenSSL 1.0.2g  1 Mar 2016'},
#  'buildEnvironment': {'distmod': 'ubuntu1604',
#   'distarch': 'x86_64',
#   'cc': '/opt/mongodbtoolchain/v2/bin/gcc: gcc (GCC) 5.4.0',
#   'ccflags': '-fno-omit-frame-pointer -fno-strict-aliasing -ggdb -pthread -Wall -Wsign-compare -Wno-unknown-pragmas -Winvalid-pch -Werror -O2 -Wno-unused-local-typedefs -Wno-unused-function -Wno-deprecated-declarations -Wno-unused-but-set-variable -Wno-missing-braces -fstack-protector-strong -fno-builtin-memcmp',
#   'cxx': '/opt/mongodbtoolchain/v2/bin/g++: g++ (GCC) 5.4.0',
#   'cxxflags': '-Woverloaded-virtual -Wno-maybe-uninitialized -std=c++14',
#   'linkflags': '-pthread -Wl,-z,now -rdynamic -Wl,--fatal-warnings -fstack-protector-strong -fuse-ld=gold -Wl,--build-id -Wl,--hash-style=gnu -Wl,-z,noexecstack -Wl,--warn-execstack -Wl,-z,relro',
#   'target_arch': 'x86_64',
#   'target_os': 'linux'},
#  'bits': 64,
#  'debug': False,
#  'maxBsonObjectSize': 16777216,
#  'storageEngines': ['devnull', 'ephemeralForTest', 'mmapv1', 'wiredTiger'],
#  'ok': 1.0}

# %%
# list records in all collections

d = dict((db, [collection for collection in client[db].list_collection_names()])
             for db in client.list_database_names())
for db in d:
    for coll in d[db]:
        # print(db, coll)
        print((client[db].command("collstats", coll))['count'], db, coll)
# Out:
# 1 admin system.version
# 2 config system.sessions
# 79 local startup_log
# 752243 we1s reddit
# 508490 we1s humanities_keywords_no_exact
# 12 we1s comparison-not-humantiies-filter
# 418302 we1s humanities_keywords
# 6607 we1s comparison-sciences-filter
# 628317 we1s comparison-sciences
# 111396 we1s deletes_humanities
# 635495 we1s comparison-not-humanities
# 47320 we1s deletes_reddit
# 44114 we1s deletes_comparison-not-humanities
# 66612 we1s deletes_comparison-sciences
# 0 we1s2018 Sources
# 548329 we1s2018 Corpus
# 1 we1s2018 testcollection

# %%
# %%time
# get estimated documents in a collection
# ...fast

count = client['we1s']['humanities_keywords'].estimated_document_count()
print(count)
# Out:
# 418302
# CPU times: user 727 µs, sys: 46 µs, total: 773 µs
# Wall time: 1.15 ms

# %%
# %%time
# get estimated documents in a collection
# ...slow, very slow

count = client['we1s']['humanities_keywords'].count_documents({})
print(count)

# %%
# %%time
# get a list of unique values for a given key
# ...very slow

key_list = client['we1s']['humanities_keywords'].distinct('pub')
print(len(key_list), key_list)

# does not give counts, just unique values
# to e.g. aggregate counts for each distinct value, see aggregation queries
# Out:
# 1557 ['Bolivian Express Magazine', 'KOCE', 'HBO', 'KCBS', 'KNBC', 'FOX_News', 'MSNBC', 'KABC', 'CNN', 'HLN', 'KCAL', 'KCET', 'KTLA', 'KTTV_FOX', 'AlJazeera', 'WEWS', 'ComedyCentral', 'WUAB', 'CSPAN', 'DigitalEphemera', 'WWW', 'CampaignAds', 'Shooters', 'Current', 'CSPAN2', None, 'School Library Journal Reviews', 'School Library Journal', 'American School & University', 'Teacher Magazine', 'Variety', '21st Century Principal', 'Newsweek', 'DailyKos', 'Amandala', 'The Houston Chronicle', 'HOUSTON CHRONICLE', 'ANDINA Peru News Agency', 'Banderas News', 'Counter-Currents', 'American Renaissance', 'College Board', 'American Thinker', 'Common Dreams', 'Arizona Daily Sun', 'Daily Dot', 'Baltimore City Paper', 'Commentary Magazine', 'Boston Review', 'Conservative Treehouse', 'Current Affairs', 'Breitbart News Network', 'Detroit Free Press', 'BuzzFeed', 'Daily Signal', 'Chronicle of Higher Education', 'Dollars and Sense', 'CityLab', 'Education Next', 'CNSNews', 'Daily Wire', 'Democracy Now', 'CounterPunch', 'Jacobin', 'LibertyNation', 'Filipino Reporter', 'Marxism-Leninism Today', 'FrontPage Magazine', 'Jewish Currents', 'Fusion', 'H-Net', 'Green Left Weekly', 'MintPress News', 'New Republic', 'Her Campus', 'LGBTQ Nation', 'Heritage Foundation', 'Jewish World Review', 'Mashable', 'Hoover Institute', 'NEA Today', 'Independent Journal Review', 'LibCom.org', 'Indian Country Media Network', 'New Left Review', 'Indymedia', 'Oath Keepers', 'Infowars', 'Inside Higher Ed', 'Mic', "It's Going Down", 'Real News Network', 'Reason Magazine', 'Newsmax', 'Rush Limbaugh', 'NewsOne.com', 'n+1', 'Shareblue Media', 'Occidental Dissent', 'Salon.com', 'Occidental Observer', 'Teach for Us', 'OZY', 'Slate Magazine', 'PeakProsperity', 'Sojourners', 'Popular Resistance', 'RedState', 'The Conversation', 'PragerU', 'PrisonPlanet', 'Splinter', 'Public Books', 'The Blaze', 'Quartz', 'SeattlePI', 'The Christian Post', 'Raw Story', 'The Nation', 'The Verge', 'Stories from School', 'The Nevada Independent', 'Think Progress', 'Talking Points Memo', 'The Nome Nugget', 'The Outline', 'The Pueblo Chieftain', 'The Christian Science Monitor', 'TownHall', 'The Daily Beast', 'The Rebel Media', 'The Daily Caller', 'TribTalk', 'The Economist', 'Truthdig', 'The Federalist', 'The Root', 'The Gateway Pundit', 'Upworthy', 'The Intercept', 'The Texas Tribune', 'This Magazine', 'VDARE', 'VICE News', 'Village Voice', 'Vox', 'Washington Free Beacon', 'Wired', 'World Socialist Web Site', 'WorldNetDaily', 'Zerohedge', 'The Hispanic Outlook in Higher Education; Paramus', 'Islamic Horizons; Plainfield', 'Southern Jewish Life; Birmingham', 'La Prensa San Diego; San Diego, Calif.', 'Diverse Issues in Higher Education; Fairfax', 'Moment; Washington', 'News from Native California; Berkeley', 'Brazzil; Los Angeles', 'Forward; New York, N.Y.', 'Russian Life; Montpelier', 'Lilith; New York', 'Black Masks; Bronx', 'US Black Engineer and Information Technology; Baltimore', '', 'El Chicano Weekly; San Bernadino , Calif.', 'Cultural Survival Quarterly; Cambridge', 'El Chicano Weekly; San Bernadino, Calif.', 'Jackson Advocate; Jackson, Miss.', 'Miami Times; Miami, Fla.', 'India Abroad; New York, N.Y.', 'The Epoch Times, New York ed.; New York (NY)', 'Washington Informer; Washington, D.C.', 'The American Israelite; Cincinnati', 'Windy City Times; Chicago, Ill.', 'India - West; San Leandro, Calif.', 'Sho - Ban News; Fort Hall, Idaho', 'Tikkun; San Francisco', 'La Voz Bilingüe; Denver, Colo.', 'Philadelphia Tribune; Philadelphia, Pa.', 'The Washington Report on Middle East Affairs; Washington', 'The Louisiana Weekly; New Orleans, La.', 'The Tennessee Tribune; Nashville, Tenn.', 'Precinct Reporter; San Bernardino, Calif.', 'La Prensa; San Antonio, Tex.', 'South Florida Times; Coral Springs, Fla.', 'The Skanner, Seattle and Portland combined edition; Seattle, Wash.', 'Windspeaker; Edmonton, Alta.', 'Chicago Jewish Star; Skokie, Ill.', 'Los Angeles Sentinel; Los Angeles, Calif.', 'Mississippi Link; Jackson ...
# 3 ['humanities', ' humanities', ' liberal_arts']
# CPU times: user 157 ms, sys: 11.1 ms, total: 168 ms
# Wall time: 4min 53s

# %%
# collection statistics
# ...very verbose

client['we1s'].command("collstats", 'humanities_keywords')
# Out:
# {'ns': 'we1s.humanities_keywords',
#  'size': 57477624093.0,
#  'count': 418302,
#  'avgObjSize': 137407,
#  'storageSize': 15226941440.0,
#  'capped': False,
#  'wiredTiger': {'metadata': {'formatVersion': 1},
#   'creationString': 'access_pattern_hint=none,allocation_size=4KB,app_metadata=(formatVersion=1),assert=(commit_timestamp=none,read_timestamp=none),block_allocation=best,block_compressor=snappy,cache_resident=false,checksum=on,colgroups=,collator=,columns=,dictionary=0,encryption=(keyid=,name=),exclusive=false,extractor=,format=btree,huffman_key=,huffman_value=,ignore_in_memory_cache_size=false,immutable=false,internal_item_max=0,internal_key_max=0,internal_key_truncate=true,internal_page_max=4KB,key_format=q,key_gap=10,leaf_item_max=0,leaf_key_max=0,leaf_page_max=32KB,leaf_value_max=64MB,log=(enabled=true),lsm=(auto_throttle=true,bloom=true,bloom_bit_count=16,bloom_config=,bloom_hash_count=8,bloom_oldest=false,chunk_count_limit=0,chunk_max=5GB,chunk_size=10MB,merge_custom=(prefix=,start_generation=0,suffix=),merge_max=15,merge_min=0),memory_page_image_max=0,memory_page_max=10m,os_cache_dirty_max=0,os_cache_max=0,prefix_compression=false,prefix_compression_min=4,source=,split_deepen_min_child=0,split_deepen_per_child=0,split_pct=90,type=file,value_format=u',
#   'type': 'file',
#   'uri': 'statistics:table:collection-64-8811390514631507301',
#   'LSM': {'bloom filter false positives': 0,
#    'bloom filter hits': 0,
#    'bloom filter misses': 0,
#    'bloom filter pages evicted from cache': 0,
#    'bloom filter pages read into cache': 0,
#    'bloom filters in the LSM tree': 0,
#    'chunks in the LSM tree': 0,
#    'highest merge generation in the LSM tree': 0,
#    'queries that could have benefited from a Bloom filter that did not exist': 0,
#    'sleep for LSM checkpoint throttle': 0,
#    'sleep for LSM merge throttle': 0,
#    'total size of bloom filters': 0},
#   'block-manager': {'allocations requiring file extension': 436828,
#    'blocks allocated': 549852,
#    'blocks freed': 135890,
#    'checkpoint size': 14560534528.0,
#    'file allocation unit size': 4096,
#    'file bytes available for reuse': 666390528,
#    'file magic number': 120897,
#    'file major version number': 1,
#    'file size in bytes': 15226941440.0,
#    'minor version number': 0},
#   'btree': {'btree checkpoint generation': 11345,
#    'column-store fixed-size leaf pages': 0,
#    'column-store internal pages': 0,
#    'column-store variable-size RLE encoded values': 0,
#    'column-store variable-size deleted values': 0,
#    'column-store variable-size leaf pages': 0,
#    'fixed-record size': 0,
#    'maximum internal page key size': 368,
#    'maximum internal page size': 4096,
#    'maximum leaf page key size': 2867,
#    'maximum leaf page size': 32768,
#    'maximum leaf page value size': 67108864,
#    'maximum tree depth': 4,
#    'number of key/value pairs': 0,
#    'overflow pages': 0,
#    'pages rewritten by compaction': 0,
#    'row-store internal pages': 0,
#    'row-store leaf pages': 0},
#   'cache': {'bytes currently in the cache': 19217683181.0,
#    'bytes dirty in the cache cumulative': 40509994772.0,
#    'bytes read into cache': 814961470789.0,
#    'bytes written from cache': 76352071610.0,
#    'checkpoint blocked page eviction': 575,
#    'data source pages selected for eviction unable to be evicted': 1010,
#    'eviction walk passes of a file': 69151,
#    'eviction walk target pages histogram - 0-9': 541,
#    'eviction walk target pages histogram - 10-31': 1068,
#    'eviction walk target pages histogram - 128 and higher': 0,
#    'eviction walk target pages histogram - 32-63': 1750,
#    'eviction walk target pages histogram - 64-128': 65792,
#    'eviction walks abandoned': 3986,
#    'eviction walks gave up because they restarted their walk twice': 1,
#    'eviction walks gave up because they saw too many pages and found no candidates': 720,
#    'eviction walks gave up because they saw too many pages and found too few candidates': 191,
#    'eviction walks reached end of tree': 3696,
#    'eviction walks started from root of tree': 4901,
#    'eviction walks started from saved location in tree': 64250,
#    'hazard pointer blocked page eviction': 344,
#    'in-memory page passed criteria to be split': 13977,
#    'in-memory page splits': 6978,
#    'internal pages evicted': 10190,
#    'internal pages split during eviction': 9,
#    'leaf pages split during eviction': 7090,
#    'modified pages evicted': 139180,
#    'overflow pages read into cache': 0,
#    'page split during eviction deepened the tree': 1,
#    'page written requiring cache overflow records': 0,
#    'pages read into cache': 5747115,
#    'pages read into cache after truncate': 1,
#    'pages read into cache after truncate in prepare state': 0,
#    'pages read into cache requiring cache overflow entries': 0,
#    'pages requested from the cache': 8593806,
#    'pages seen by eviction walk': 13250326,
#    'pages written from cache': 549481,
#    'pages written requiring in-memory restoration': 0,
#    'tracked dirty bytes in the cache': 0,
#    'unmodified pages evicted': 5594623},
#   'cache_walk': {'Average difference between current eviction generation when the page was last considered': 0,
#    'Average on-disk page image size seen': 0,
#    'Average time in cache for pages that have been visited by the eviction server': 0,
#    'Average time in cache for pages that have not been visited by the eviction server': 0,
#    'Clean pages currently in cache': 0,
#    'Current eviction generation': 0,
#    'Dirty pages currently in cache': 0,
#    'Entries in the root page': 0,
#    'Internal pages currently in cache': 0,
#    'Leaf pages currently in cache': 0,
#    'Maximum difference between current eviction generation when the page was last considered': 0,
#    'Maximum page size seen': 0,
#    'Minimum on-disk page image size seen': 0,
#    'Number of pages never visited by eviction server': 0,
#    'On-disk page image sizes smaller than a single allocation unit': 0,
#    'Pages created in memory and never written': 0,
#    'Pages currently queued for eviction': 0,
#    'Pages that could not be queued for eviction': 0,
#    'Refs skipped during cache traversal': 0,
#    'Size of the root page': 0,
#    'Total number of pages currently in cache': 0},
#   'compression': {'compressed pages read': 5736020,
#    'compressed pages written': 543111,
#    'page written failed to compress': 0,
#    'page written was too small to compress': 6370},
#   'cursor': {'bulk-loaded cursor-insert calls': 0,
#    'close calls that result in cache': 0,
#    'create calls': 23,
#    'cursor operation restarted': 0,
#    'cursor-insert key and value bytes inserted': 76195949890.0,
#    'cursor-remove key bytes removed': 0,
#    'cursor-update value bytes updated': 0,
#    'cursors reused from cache': 685146,
#    'insert calls': 551720,
#    'modify calls': 0,
#    'next calls': 7111261,
#    'open cursor count': 0,
#    'prev calls': 1,
#    'remove calls': 0,
#    'reserve calls': 0,
#    'reset calls': 1648588,
#    'search calls': 266837,
#    'search near calls': 144060,
#    'truncate calls': 0,
#    'update calls': 0},
#   'reconciliation': {'dictionary matches': 0,
#    'fast-path pages deleted': 0,
#    'internal page key bytes discarded using suffix compression': 410669,
#    'internal page multi-block writes': 616,
#    'internal-page overflow keys': 0,
#    'leaf page key bytes discarded using prefix compression': 0,
#    'leaf page multi-block writes': 7129,
#    'leaf-page overflow keys': 0,
#    'maximum blocks required for a page': 1,
#    'overflow values written': 0,
#    'page checksum matches': 27086,
#    'page reconciliation calls': 141925,
#    'page reconciliation calls for eviction': 90560,
#    'pages deleted': 199},
#   'session': {'object compaction': 0},
#   'transaction': {'update conflicts': 0}},
#  'nindexes': 1,
#  'indexDetails': {'_id_': {'metadata': {'formatVersion': 8,
#     'infoObj': '{ "v" : 2, "key" : { "_id" : 1 }, "name" : "_id_", "ns" : "we1s.humanities_keywords" }'},
#    'creationString': 'access_pattern_hint=none,allocation_size=4KB,app_metadata=(formatVersion=8,infoObj={ "v" : 2, "key" : { "_id" : 1 }, "name" : "_id_", "ns" : "we1s.humanities_keywords" }),assert=(commit_timestamp=none,read_timestamp=none),block_allocation=best,block_compressor=,cache_resident=false,checksum=on,colgroups=,collator=,columns=,dictionary=0,encryption=(keyid=,name=),exclusive=false,extractor=,format=btree,huffman_key=,huffman_value=,ignore_in_memory_cache_size=false,immutable=false,internal_item_max=0,internal_key_max=0,internal_key_truncate=true,internal_page_max=16k,key_format=u,key_gap=10,leaf_item_max=0,leaf_key_max=0,leaf_page_max=16k,leaf_value_max=0,log=(enabled=true),lsm=(auto_throttle=true,bloom=true,bloom_bit_count=16,bloom_config=,bloom_hash_count=8,bloom_oldest=false,chunk_count_limit=0,chunk_max=5GB,chunk_size=10MB,merge_custom=(prefix=,start_generation=0,suffix=),merge_max=15,merge_min=0),memory_page_image_max=0,memory_page_max=5MB,os_cache_dirty_max=0,os_cache_max=0,prefix_compression=true,prefix_compression_min=4,source=,split_deepen_min_child=0,split_deepen_per_child=0,split_pct=90,type=file,value_format=u',
#    'type': 'file',
#    'uri': 'statistics:table:index-65-8811390514631507301',
#    'LSM': {'bloom filter false positives': 0,
#     'bloom filter hits': 0,
#     'bloom filter misses': 0,
#     'bloom filter pages evicted from cache': 0,
#     'bloom filter pages read into cache': 0,
#     'bloom filters in the LSM tree': 0,
#     'chunks in the LSM tree': 0,
#     'highest merge generation in the LSM tree': 0,
#     'queries that could have benefited from a Bloom filter that did not exist': 0,
#     'sleep for LSM checkpoint throttle': 0,
#     'sleep for LSM merge throttle': 0,
#     'total size of bloom filters': 0},
#    'block-manager': {'allocations requiring file extension': 273,
#     'blocks allocated': 899,
#     'blocks freed': 208,
#     'checkpoint size': 3985408,
#     'file allocation unit size': 4096,
#     'file bytes available for reuse': 65536,
#     'file magic number': 120897,
#     'file major version number': 1,
#     'file size in bytes': 4071424,
#     'minor version number': 0},
#    'btree': {'btree checkpoint generation': 11345,
#     'column-store fixed-size leaf pages': 0,
#     'column-store internal pages': 0,
#     'column-store variable-size RLE encoded values': 0,
#     'column-store variable-size deleted values': 0,
#     'column-store variable-size leaf pages': 0,
#     'fixed-record size': 0,
#     'maximum internal page key size': 1474,
#     'maximum internal page size': 16384,
#     'maximum leaf page key size': 1474,
#     'maximum leaf page size': 16384,
#     'maximum leaf page value size': 7372,
#     'maximum tree depth': 3,
#     'number of key/value pairs': 0,
#     'overflow pages': 0,
#     'pages rewritten by compaction': 0,
#     'row-store internal pages': 0,
#     'row-store leaf pages': 0},
#    'cache': {'bytes currently in the cache': 23087,
#     'bytes dirty in the cache cumulative': 41214201,
#     'bytes read into cache': 5664425,
#     'bytes written from cache': 6193648,
#     'checkpoint blocked page eviction': 0,
#     'data source pages selected for eviction unable to be evicted': 3,
#     'eviction walk passes of a file': 15220,
#     'eviction walk target pages histogram - 0-9': 15220,
#     'eviction walk target pages histogram - 10-31': 0,
#     'eviction walk target pages histogram - 128 and higher': 0,
#     'eviction walk target pages histogram - 32-63': 0,
#     'eviction walk target pages histogram - 64-128': 0,
#     'eviction walks abandoned': 113,
#     'eviction walks gave up because they restarted their walk twice': 14682,
#     'eviction walks gave up because they saw too many pages and found no candidates': 1,
#     'eviction walks gave up because they saw too many pages and found too few candidates': 0,
#     'eviction walks reached end of tree': 29786,
#     'eviction walks started from root of tree': 15071,
#     'eviction walks started from saved location in tree': 149,
#     'hazard pointer blocked page eviction': 3,
#     'in-memory page passed criteria to be split': 20,
#     'in-memory page splits': 10,
#     'internal pages evicted': 0,
#     'internal pages split during eviction': 0,
#     'leaf pages split during eviction': 11,
#     'modified pages evicted': 11,
#     'overflow pages read into cache': 0,
#     'page split during eviction deepened the tree': 0,
#     'page written requiring cache overflow records': 0,
#     'pages read into cache': 388,
#     'pages read into cache after truncate': 1,
#     'pages read into cache after truncate in prepare state': 0,
#     'pages read into cache requiring cache overflow entries': 0,
#     'pages requested from the cache': 551731,
#     'pages seen by eviction walk': 32857,
#     'pages written from cache': 604,
#     'pages written requiring in-memory restoration': 0,
#     'tracked dirty bytes in the cache': 0,
#     'unmodified pages evicted': 388},
#    'cache_walk': {'Average difference between current eviction generation when the page was last considered': 0,
#     'Average on-disk page image size seen': 0,
#     'Average time in cache for pages that have been visited by the eviction server': 0,
#     'Average time in cache for pages that have not been visited by the eviction server': 0,
#     'Clean pages currently in cache': 0,
#     'Current eviction generation': 0,
#     'Dirty pages currently in cache': 0,
#     'Entries in the root page': 0,
#     'Internal pages currently in cache': 0,
#     'Leaf pages currently in cache': 0,
#     'Maximum difference between current eviction generation when the page was last considered': 0,
#     'Maximum page size seen': 0,
#     'Minimum on-disk page image size seen': 0,
#     'Number of pages never visited by eviction server': 0,
#     'On-disk page image sizes smaller than a single allocation unit': 0,
#     'Pages created in memory and never written': 0,
#     'Pages currently queued for eviction': 0,
#     'Pages that could not be queued for eviction': 0,
#     'Refs skipped during cache traversal': 0,
#     'Size of the root page': 0,
#     'Total number of pages currently in cache': 0},
#    'compression': {'compressed pages read': 0,
#     'compressed pages written': 0,
#     'page written failed to compress': 0,
#     'page written was too small to compress': 0},
#    'cursor': {'bulk-loaded cursor-insert calls': 0,
#     'close calls that result in cache': 0,
#     'create calls': 11,
#     'cursor operation restarted': 0,
#     'cursor-insert key and value bytes inserted': 7266270,
#     'cursor-remove key bytes removed': 0,
#     'cursor-update value bytes updated': 0,
#     'cursors reused from cache': 551710,
#     'insert calls': 418302,
#     'modify calls': 0,
#     'next calls': 0,
#     'open cursor count': 0,
#     'prev calls': 0,
#     'remove calls': 0,
#     'reserve calls': 0,
#     'reset calls': 1103442,
#     'search calls': 133419,
#     'search near calls': 0,
#     'truncate calls': 0,
#     'update calls': 0},
#    'reconciliation': {'dictionary matches': 0,
#     'fast-path pages deleted': 0,
#     'internal page key bytes discarded using suffix compression': 8078,
#     'internal page multi-block writes': 0,
#     'internal-page overflow keys': 0,
#     'leaf page key bytes discarded using prefix compression': 35945510,
#     'leaf page multi-block writes': 147,
#     'leaf-page overflow keys': 0,
#     'maximum blocks required for a page': 1,
#     'overflow values written': 0,
#     'page checksum matches': 1376,
#     'page reconciliation calls': 304,
#     'page reconciliation calls for eviction': 0,
#     'pages deleted': 0},
#    'session': {'object compaction': 0},
#    'transaction': {'update conflicts': 0}}},
#  'totalIndexSize': 4071424,
#  'indexSizes': {'_id_': 4071424},
#  'ok': 1.0}

# %% [markdown]
# ## Basic insert, find, delete

# %%
# you can create multiple database or collection objects.
# the way to create a new database or collection is to define it and write to it.

# both the database and the collection are not yet created
db = client['temp_db']
temp_corpus = db['temp_corpus']

# they are created when the first document is written.
temp_corpus.insert_one({'field': 'DELETEME'})

# confirm the document was added and assigned an _id
print(temp_corpus.find_one())

# db and collection are NOT deleted when the all documents are deleted
temp_corpus.delete_many({'field': {'$eq' : 'DELETEME'}})

# list all collections in a database:
print('collections: ', db.list_collection_names())

# list all databases on mongodb instance:
print('databases: ', client.list_database_names())

# cleaning up:
#   a collection can be deleted with drop
temp_corpus.drop()
#   a database can be deleted from the client by object or name
#   -- name is safer if using generic code with a db object
#   such as in a Jupyter testing notebook
client.drop_database('temp_db')
#   the temp_db database is now gone:
print('databases: ', client.list_database_names())

# re-define the default collection for all tests below
db = client['we1s']
corpus = db['Corpus']

# %%
# COPY DATABASE TO NEW NAME AND DELETE/DROP OLD
# This is the closest thing mongodb has to a rename database command.
# It duplicates all data during the copy operation

client.admin.command('copydb',
                     fromdb='we1s-old',
                     todb='we1s-new')
client.drop_database('we1s-old')

# %% [markdown]
# ## Queries

# %%
# a query is a python dict.
# define a query for: all jons with "Angeles" in the pub field 
query = {'pub': {'$regex':'.*Angeles.*'}}
# query = {'name': {'$regex':'.*thewallstreetjournal.*'}}

# retrieve a document
one_doc = client['we1s']['humanities_keywords'].find_one(query, {'features':0, 'language_model':0})

# display a document
one_doc['content'] = one_doc['content'][0:500] + '[...]' # snip content for preview readability
# print("one_doc:\n", one_doc, '\n')
pp.pprint(one_doc)



docs = client['we1s']['humanities_keywords'].aggregate([{ '$sample': { 'size': 3 } }])

for doc in docs:
    if 'features' in doc:
        doc.pop('features')
    if 'language_model' in doc:
        doc.pop('language_model')
    if 'content-unscrubbed' in doc:
        doc.pop('content-unscrubbed')
    doc['content'] = doc['content'][0:500] + '[...]'
    pp.pprint(doc)
# Out:
# { '_id': ObjectId('5d3ab969f123b8357f43969d'),
#   'attachment-id': '',
#   'author': 'By Lester C. Thurow',
#   'content': ' WHEN IT COMES to inventing new technologies, America has no '
#              'peers. More than a proportionate share of new ideas are still '
#              'American ideas. It was not always so. Prior to World War II, '
#              'basic scientific breakthroughs tended to come from Europe. Then, '
#              'for two or three decades after World War II, America had '
#              'effortless technological superiority --it had no peers either as '
#              'an inventor or user of new technologies. Now that era is gone, '
#              'too. America faces foreign competitors -- Japan, West Germany, '
#              'Sou[...]',
#   'content-hash-ssdeep': '192:gEo7m2G3333s3MzzzzVQyYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYTre6CtttO:gEx2lDyYYYYYYYYYYYYYYYYYYYYYYYYx',
#   'copyright': 'Wall Street Journal , Eastern edition; New York, N.Y. [New '
#                'York, N.Y]12 June 1987: 1.',
#   'database': 'Global Newsstream',
#   'doc_id': 'DocID_MSTAR_398032431',
#   'issue': '',
#   'length': 7913,
#   'metapath': 'Corpus,proquest,proquest_thewallstreetjournal_humanities_1984_1989_129_',
#   'name': 'proquest_thewallstreetjournal_humanities_1984_1989_129_',
#   'namespace': 'we1sv2.0',
#   'ppversion': '0.1',
#   'pub': 'Wall Street Journal, Eastern edition; New York, N.Y.',
#   'pub_date': '1987-06-12T00:00:00Z',
#   'raw_date': 'Jun 12, 1987',
#   'readability_scores': [ 42.11763476680801,
#                           12.238661417322835,
#                           9.093946274984859],
#   'section': '',
#   'sources': ['thewallstreetjournal'],
#   'title': 'Technology (A Special Report): Viewpoint --- The Task at Hand: '
#            "After Decades of Excuses, It's Time for American Managers to Learn "
#            'Technology',
#   'volume': '',
#   'word_count': 1279}

# %%
result = client['we1s']['humanities_keywords'].find_one({'pub_date': ''})

print(result)
# Out:
# {'_id': ObjectId('5d3a98b1f123b8357f3c89b7'), 'doc_id': '02A6A252C52394AB97B14672E56C2F2F4F90A529D0561AD49F00CEDD2F664699C866F0EE71FC8C267F54EC7271BA873CEF5C6814683C799579950948989D66E2685A0B7A65C70808142051ACB1A0A249FEC8409EB8A86BB611B574F2927FD1D66CAB33485CF58E00CC3D383B19CF903E', 'attachment_id': '', 'pub': 'School Library Journal Reviews', 'pub_date': '', 'length': '332', 'section': 'MULTIMEDIA REVIEW; Video/DVD; Pg. 69', 'author': 'MaryAnn Karre', 'title': 'Playing to Win;  The College Admissions Experience; Getting an Edge: Early Admission; Admit, Defer, or Reject: The Admissions Perspective; Accept or Decline: The Applicant Perspective', 'copyright': '<br/>', 'content-unscrubbed': '(Series). 3 videocassettes or 3 DVDs. color. range 22-23 min. Prod. by ABC News. Dist. by Films for the Humanities & Sciences. 2003. video: $239.95 ser., $89.95 ea.; DVD: $269.95 ser., $99.95 ea. Includes: (ISBN 0-7365-8193-7); (ISBN 0-7365-8193-6); (ISBN 0-7365-8197-9). Gr 10-12 - These productions are a compilation of an ABC Nightlineprogram that was originally titled Class Action and broadcast on May 23, 2003. Getting an Edge: Early Admissiondeals with the beginning of the application process, and touches upon the early admission or early acceptance policies of colleges. Viewers are introduced to applicants, their parents and counselors, and the admissions counselors and deans of admissions of colleges. As the ABC Nightline team follows three high school students from the Washington, DC area, they discuss how to select a college, how to deal with the pressure of the application process, and how colleges market themselves to students. The influences of college rankings and test scores are discussed, as are unfair advantages of socioeconomic class and the perceived advantages of race. In Admit, Defer or Reject, we follow three applicants to Georgetown University through the process, and watch the college admissions committee process their applications. Accept or Decline summarizes the processes described in the first two videos, and offers advice to students and their parents based on the inside information gained through the access to Georgetown\'s admissions process. There is some duplication of information between programs, but each offers a different perspective. The opportunity to see what goes on behind the doors of a prestigious university and to hear how applicants are "graded" on the basis of their essays and scores will help students who are facing the grueling process of applying to colleges. Parents and counselors will profit from the advice offered here as well. - MaryAnn Karre, Horace Mann Elementary School, Binghamton, NY', 'content': '(Series). 3 videocassettes or 3 DVDs. color. range 22-23 min. Prod. by ABC News. Dist. by Films for the Humanities & Sciences. 2003. video: $239. 95 ser., $89. 95 ea.; DVD: $269. 95 ser., $99. 95 ea. Includes: (ISBN 0-7365-8193-7); (ISBN 0-7365-8193-6); (ISBN 0-7365-8197-9). Gr 10-12 - These productions are a compilation of an ABC Nightlineprogram that was originally titled Class Action and broadcast on May 23, 2003. Getting an Edge: Early Admissiondeals with the beginning of the application process, and touches upon the early admission or early acceptance policies of colleges. Viewers are introduced to applicants, their parents and counselors, and the admissions counselors and deans of admissions of colleges. As the ABC Nightline team follows three high school students from the Washington, DC area, they discuss how to select a college, how to deal with the pressure of the application process, and how colleges market themselves to students. The influences of college rankings and test scores are discussed, as are unfair advantages of socioeconomic class and the perceived advantages of race. In Admit, Defer or Reject, we follow three applicants to Georgetown University through the process, and watch the college admissions committee process their applications. Accept or Decline summarizes the proce ...

# %%
results = client['we1s']['humanities_keywords'].find({'pub_date':{'$exists': False}, 'raw_date':{'$exists': False}},{'Age': 1, '_id':0})

hits = 0
for rec2 in results:
    hits += 1
    print(rec2['name'])
print('\nHits: ', hits)

# %% [markdown]
# ## Counting query results
#
# Rather than receiving a list of results and counting the list,
# ask the database for a count directly.

# %%
# get a count of how many documents match the query
# NOTE: does not take a projection argument

count = corpus.count_documents(query)
print("count:", count)
print(count)

# %%
# compare two query counts

query = { 'name': {'$regex':'.*humanities.*' }}
count = corpus.count_documents(query)
query = { 'name': {'$regex':'.*liberal.*' }}
count2 = corpus.count_documents(query)
print("counts:", count, count2, '\n')

# %% [markdown]
# ## Results: using cursors
#
# Unlike a generator, a cursor is random access -- however it isn't populated until you try to access it.

# %%
# Access results by index

# create a cursor on a search
query = { 'name': {'$regex':'.*humanities.*' }}
projection = { 'content':0 }
result_set = corpus.find(query, projection)
# this is a cursor object, not a list of results:
print(result_set, '\n')
# random access to mongodb -- don't need to iterate in order
print(result_set[5], '\n')
print(result_set[0], '\n')

# %%
# Use limit to limit a set of results by index

# create a cursor on a search
query = { 'name': {'$regex':'.*humanities.*' }}
projection = { 'content':0 }
result_set = corpus.find(query, projection).limit(3)
# this is a cursor object, not a list of results:
print(result_set, '\n')
# weirdly the cursor can still be used to access records outside the limit until it is iterated over
# and limit does not influence count
# ...for more, see https://stackoverflow.com/questions/29604573/how-to-limit-mongo-query-in-python
print(result_set[5], '\n')
# iterate over list -- this empties it
for result in result_set:
    print(result, '\n')
# print(result_set[0], '\n') # this now causes an error

# %%
# Randomly selected results

# create a cursor on a search
query = { 'name': {'$regex':'.*humanities.*' }}
projection = { '_id':1 }
result_set = corpus.find(query, projection)
# create list of full cursor contents 
result_list = list(result_set)
# print(result_list[200])
import random
print('Download full list and get three random docs:\n', random.sample(result_list, 3), '\n')

# %% [markdown]
# ## Insert records

# %%
corpus.index_information()

# you can create a document and insert it.

insert = {'doc_id': 'INSERT_TEST',
          'title': 'Fake Article Title',
         }

# on insert_one, an InsertOne object is returned.
# it can be queried for the _id of what was just inserted.

insert_id = corpus.insert_one(insert)
print(insert_id.inserted_id)

# clean up: delete the document
query = { 'doc_id': {'$eq': 'INSERT_TEST' }}
dels = corpus.delete_many(query)
print(dels.deleted_count, " documents deleted.")

# %%
# identical documents will be inserted with
# a different _id field.

corpus.insert_one({'doc_id': 'INSERT_TEST',
                   'title': 'Fake Article Title',
                  })
corpus.insert_one({'doc_id': 'INSERT_TEST',
                   'title': 'Fake Article Title',
                  })

# results: two identical documents with different _ids

query = { 'doc_id': {'$eq': 'INSERT_TEST' }}
result_set = corpus.find(query)
for result in result_set:
    print(result)

# clean up: delete test documents

dels = corpus.delete_many(query)
print(dels.deleted_count, " documents deleted.")

# %%
# %%time

# 

insert = {'doc_id': 'INSERT_TEST',
           'title': 'Fake Article Title',
          }
insert_id = corpus.insert_one(insert)
print(insert_id.inserted_id)

# each document used for inserting
# also has _id silently to the python dict.

print("insert['_id']:", insert['_id'])

# this generates a key error if you try to insert the
# same object twice, as you are trying to insert an _id
# that already exists--which may be what you want,
# but could be surprising if you are modifying a dict
# on the fly and using it for repeated writes.
# discussion: https://stackoverflow.com/questions/17529216/mongodb-insert-raises-duplicate-key-error

insert3 = {'doc_id': 'INSERT_TEST',
           'title': 'Fake Article Title',
          }
try:
    insert_id = corpus.insert_one(insert3)
    print(insert_id.inserted_id)
    insert_id = corpus.insert_one(insert3)
    print(insert_id.inserted_id)
except (DuplicateKeyError) as err:
    print(err)

# %%
test_insert = {'_id': 'abc',
               'doc_id': 'DELETEME',
               'pub': 'Fake Publication',
               'title': 'Fake Article Title',
              }

insert_id = corpus.insert_one(test_insert)
print(insert_id.inserted_id)
query = { 'doc_id': {'$eq': 'DELETEME' }}
result_set = corpus.find(query)
for result in result_set:
    print(result)

# %%
# upsert -- either add or update documents

# https://stackoverflow.com/questions/44462399/how-to-handle-duplicatekeyerror-in-mongodb-pymongo    
# for doc in documents:
#     client.update_one({'_id': doc['_id']}, doc, upsert=True)

# %% [markdown]
# ## Projection: limiting which fields are returned

# %%
# The projection field controls what record fields are returned.
# It is either inclusive or exclusive.

query = {'name': {'$regex': '.*newyorktimes.*'}}

# create a projection that shows only selected fields
print('selected doc:\n', corpus.find_one(query, {'name':1, 'pub':1, 'title':1}), '\n')

# create a projection that shows everything but content
print('no content doc:\n', corpus.find_one(query, {'content':0}), '\n')

# _id is always included, but you can exclude it explicitly
print('no _id, name only doc:\n', corpus.find_one(query, {'_id':0, 'name':1}), '\n')

# once the object is returned, fields can be further manipulated --
# -- for example, showing a preview of long content

# content only projection, transformed to preview (shortened for readability)
one_doc = corpus.find_one(query, {'content':1})
one_doc['content_preview'] = one_doc.pop('content')[0:400] + '[...]'
print('content only (shortened):\n', one_doc, '\n')


# you cannot combine inclusion and exclusion statements in projection documents
# -- with the exception of the _id field.

# %% [markdown]
# ## Search with multiple terms

# %%
# define a query for: name contains "newyorktimes" with a pub_date beginning with 2016
query = {'name': {'$regex':'.*newyorktimes.*'}, 'pub_date': {'$regex':'2016.*'}}
count = corpus.count_documents(query)
print("count:", count)

# example
print("example:\n", corpus.find_one(query, {'content':0}),'\n')

# %%
# %%time

# define and run a complex regular expression:
#   humanities NOT liberal

query = { 'name': {'$regex':'^(?!.*liberal).*humanities.*'}}
count = corpus.count_documents(query)
print("count:", count, '\n')

# ...when possible this may be ~2x faster with mongodb operators, see below

# %%
# %%time

# define and run a complex search:
#   humanities NOT liberal

query = { '$and': [ { 'name': { '$regex':'.*humanities.*' } }, { 'name': { '$not': { '$regex':'.*liberal.*' } } } ] }
count = corpus.count_documents(query)
print("count:", count, '\n')

# %%
# we could potentially make this much faster with text indexing,
# although it has very specific limitations

# https://medium.com/statuscode/how-to-speed-up-mongodb-regex-queries-by-a-factor-of-up-to-10-73995435c606

# %% [markdown]
# ## Query printing
#
# Methods of displaying pymongo mongodb queries in readable formats.

# %%
# pymongo queries are python dicts of dicts (or lists of dicts)
# however, these nested lines can be very hard to read

# print a query dict
query = {'$or': [{'name': {'$regex': '.*liberal.*'}}, {'name': {'$regex': '.*humanities.*'}}]}
print("\nprint dict:\n", query)
# Out:
# print dict:
#  {'$or': [{'name': {'$regex': '.*liberal.*'}}, {'name': {'$regex': '.*humanities.*'}}]}

# %%
# pprint adds linebreaks and indents
import pprint
pp = pprint.PrettyPrinter(indent=4, compact=False)
print("\nprint with PrettyPrinter:")
pp.pprint(query)
# Out:
# print with PrettyPrinter:
# {   '$or': [   {'name': {'$regex': '.*liberal.*'}},
#                {'name': {'$regex': '.*humanities.*'}}]}

# %%
# json can also be used to print nested dict/lists
# in a more articulated indented outline form

query = {'$or': [{'name': {'$regex': '.*liberal.*'}}, {'name': {'$regex': '.*humanities.*'}}]}
import json
def jsonprint(obj):
    print(json.dumps(obj, sort_keys=True, indent=4))
print("\nprint with json:")
jsonprint(query)
# Out:
# print with json:
# {
#     "$or": [
#         {
#             "name": {
#                 "$regex": ".*liberal.*"
#             }
#         },
#         {
#             "name": {
#                 "$regex": ".*humanities.*"
#             }
#         }
#     ]
# }

# %% [markdown]
# ## Databases: rename-by-copy

# %%
# %%time
## extremely slow--and potentially not safe if name already exists

# COPY DATABASE TO NEW NAME AND DELETE/DROP OLD

# client.admin.command('copydb',
#                      fromdb='we1s',
#                      todb='we1s-test')
# Out:
# CPU times: user 8 µs, sys: 2 µs, total: 10 µs
# Wall time: 22.4 µs

# %% [markdown]
# ## Databases: drop

# %%
# client.drop_database('we1s')
